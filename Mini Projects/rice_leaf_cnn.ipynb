# %% [markdown]
# # PROJECT TEAM ID: PTID-CDS-NOV-23-1700

# %% [markdown]
# # CAPSTONE PROJECT: PRCP-1001-RiceLeaf

# %% [markdown]
# ## Problem Statement
#
#     Task 1:-Prepare a complete data analysis report on the given data.
#
#     Task 2:-Create a model which can classify the three major attacking diseases of
#     rice plants like leaf blast, bacterial blight and brown spot.
#
#     Task3:- Analyze various techniques like Data Augmentation, etc and create a
#     report on that.

# %% [markdown]
# ## Dataset
#
#
#     The dataset contains 120 jpg images of disease-infected rice leaves. The images are grouped into 3
#     classes based on the type of disease. There are 40 images in each class.
#     Classes
#         ● Leaf smut
#         ● Brown spot
#         ● Bacterial leaf blight

# %% [markdown]
# ## Importing necessary libraries

# %%
# install library for tensorflow    
# %pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: tensorflow in c:\users\mayank\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\mayank\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.7.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\mayank\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\mayank\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\mayank\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\mayank\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\mayank\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mayank\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mayank\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mayank\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mayank\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\mayank\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\mayank\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\mayank\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\mayank\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mayank\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mayank\appdata\roaming\python\python312\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mayank\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# install library for computer-vision
# %pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: opencv-python in c:\users\mayank\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\mayank\anaconda3\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing necessary libraries

# NumPy for numerical operations
import numpy as np

# Pandas for data manipulation
import pandas as pd

# Seaborn for statistical data visualization
import seaborn as sns

# Random for generating random numbers
import random 

# Matplotlib for plotting
import matplotlib.pyplot as plt

# Matplotlib function to read images
from matplotlib.image import imread

# OpenCV for computer vision tasks
import cv2

# OS for interacting with the operating system
import os

# Keras utilities for image processing
from tensorflow.keras.utils import img_to_array, array_to_img, load_img

# TensorFlow for deep learning
import tensorflow as  tf


# Importing specific modules from Keras
from tensorflow import keras
from keras import layers

# Keras models for building neural networks
from keras.models import Model, Sequential


from keras.layers import Input, Lambda

# Keras layers for building neural networks
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D, MaxPooling2D, BatchNormalization
from keras.models import Model  

# Keras module for image preprocessing
from keras.preprocessing import image

# Keras module for image data augmentation
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential

# Glob for finding all pathnames matching a specified pattern
from glob import glob

# Ignoring warnings for cleaner output
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load the data and visulaize the data with respect to each class

# %% [markdown]
# ### 1. Bacterial Leaf Blight

# %%
# For Bacterial leaf blight

# Set the size of the entire figure
plt.figure(figsize = (12, 12))

# Specify the path to the directory containing bacterial leaf blight images
bacteria_path = r"Data\Bacterial leaf blight"

# Loop through subplots (7 rows x 3 columns)
for i in range(1, 22):
    
    # Create a subplot in the specified grid
    plt.subplot(7, 3, i)
    
    # Adjust layout for better spacing
    plt.tight_layout()
    
    # Randomly choose an image from the specified directory
    rand_img = plt.imread(bacteria_path +'/'+ random.choice(sorted(os.listdir(bacteria_path))))
    plt.imshow(rand_img)
    
    # Display the image in the subplot
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    
    # Set the y-axis label to the height of the image
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %% [markdown]
# ### 2. Brown Spot

# %%
# For brown spot

# Set the size of the entire figure
plt.figure(figsize = (12, 12))

# Path to the directory containing images (assuming it's a relative path)
bacteria_path = r"Data/Brown spot"

# Loop through subplots
for i in range(1, 22):
    
    # Create a subplot in a 7x3 grid, and select the i-th subplot
    plt.subplot(7, 3, i)
    
    # Adjust the layout to prevent overlapping subplots
    plt.tight_layout()
    
    # Choose a random image from the directory using os.listdir and random.choice
    rand_img = plt.imread(bacteria_path +'/'+ random.choice(sorted(os.listdir(bacteria_path))))
    
    # Display the image in the current subplot
    plt.imshow(rand_img)
    
    # Set the x-axis label to the width of the image
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    
    # Set the y-axis label to the height of the image
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %% [markdown]
# ### 3. Leaf Smut

# %%
# for leaf smut

# Set the figure size for the entire plot
plt.figure(figsize = (12, 12))

# Define the path where the leaf smut bacteria images are stored
bacteria_path = r"Data\Leaf smut"

# Loop through a range of values from 1 to 21
for i in range(1, 22):
    
    # Create subplots in a 7x3 grid, and set the current subplot to i
    plt.subplot(7, 3, i)
    
    # Adjust layout for better spacing
    plt.tight_layout()
    
    # Get a random image from the specified path
    rand_img = plt.imread(bacteria_path +'/'+ random.choice(sorted(os.listdir(bacteria_path))))
    
    # Display the image
    plt.imshow(rand_img)
    
    # Set the x-axis label to the width of the image
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    
    # Set the y-axis label to the height of the image
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %% [markdown]
# ## Data preprocessing and data augmentation

# %% [markdown]
# ### ImageDataGenerator is used below to perform data augmentation from keras
#
# 1. ImageDataGenerator Configuration:
#
#     An instance of ImageDataGenerator is created with various augmentation parameters such as rotation_range, width_shift_range, height_shift_range, shear_range, zoom_range, horizontal_flip, and fill_mode. These parameters control the types and degrees of random transformations applied to the input image.
#
#
#
# 2. Loading and Preparing the Image:
#
#     An image (DSC_0121.jpg) is loaded using the load_img function from Keras. This image is then converted to a Numpy array using img_to_array, and its shape is adjusted to have a batch dimension of 1.
#
#
#
# 3. Data Augmentation and Saving:
#
#     The .flow() method of the ImageDataGenerator is used to generate batches of randomly transformed images from the single input image (x). The generated images are saved to the specified directory (Image Augmentation Example) with filenames prefixed by 'rice_leaf_brown_spot' and saved in JPEG format.
#
#     The loop (for batch in datagen.flow(x, batch_size=1, ...):) iterates over the augmented images, and the loop is limited to 20 iterations (if i > 20: break) to avoid an infinite loop.

# %% [markdown]
# #### 1. Create an ImageDataGenerator for training data with specified augmentation parameters

# %%
# Create an ImageDataGenerator for training data with specified augmentation parameters

train_datagen = ImageDataGenerator(
                                   # Rotation range for random rotations (degrees)
                                   rotation_range=40,
                                   
                                   # Width shift range for random horizontal shifts
                                   width_shift_range=0.2,
                                   
                                   # Height shift range for random vertical shifts
                                   height_shift_range=0.2,
                                   
                                   # Normalize pixel values to be between 0 and 1
                                   rescale=1./255,
                                   
                                   # Shear range for random shearing
                                   shear_range=0.2,
                                   
                                   # Zoom range for random zooming
                                   zoom_range=0.2,
                                   
                                   # Randomly flip images horizontally
                                   horizontal_flip=True,
                                   
                                   # Strategy for filling in newly created pixels (nearest pixel strategy)
                                   fill_mode='nearest',
                                   
                                   # Fraction of images to reserve for validation (25% of the data)
                                   validation_split = .25)

# %% [markdown]
# #### 2. Create an ImageDataGenerator for test data with rescaling and validation split

# %%
# Create an ImageDataGenerator for test data with rescaling and validation split

test_datagen = ImageDataGenerator(
                                  
                                  # Normalize pixel values to be between 0 and 1
                                  rescale=1./255,
                                  
                                  # Fraction of images to reserve for validation (25% of the data)
                                  validation_split = .25)

# %%
# ImageDataGenerator is used below to perform data augmentation from keras
datagen = ImageDataGenerator(
        
        # A range within which to randomly rotate images (in degrees)
        rotation_range=40,
        
        # The range for randomly shifting the width of images
        width_shift_range=0.2,
        
        # The range for randomly shifting the height of images
        height_shift_range=0.2,
        
        # Shear intensity (shear mapping is a linear map that displaces each point in fixed direction).
        shear_range=0.2,
        
        # Random zoom range
        zoom_range=0.2,
        
        # Randomly flip images horizontally
        horizontal_flip=True,
        
        # Strategy for filling in newly created pixels, in this case, 'nearest' is used
        fill_mode='nearest')



# Load an image to specified path
img = load_img(r"Data\Brown spot\DSC_0121.jpg") 

# Convert the image to numpy array
x = img_to_array(img)  

# Reshape the numpy array to have batch of dimension 1  
x = x.reshape((1,) + x.shape) 


# Initialize a counter for the number of augmented images generated
i = 0

# Loop over batches of augmented images generated by datagen
for batch in datagen.flow(x, batch_size=1, save_to_dir=r"Data Augmentation", save_prefix='rice_leaf_brown_spot', save_format='jpeg'):
        
    # Increment the counter    
    i += 1
    
    
    # Check if the desired number of augmented images (20 in this case) has been reached
    if i > 20:
            
        # If the desired number is reached, exit the loop to avoid generating more images
        break

# %% [markdown]
# ## Displaying a Grid of Augment Brown Spot Rice Leaf Image

# %%
# Displaying a Grid of Augment Brown Spot Rice Leaf Image

# Set up the plotting figure
plt.figure(figsize=(12,12))

# Specify augmented image directory
path = r"Data Augmentation"

# Display the augmented images
for i in range(1,13):
    
    # Create Subplots in a 4x3 Grid
    plt.subplot(4,3,i)
    
    # Ensure Tight Layout
    plt.tight_layout()
    
    # Select a Random Image from the Augmented Images Directory
    rand_img = imread(path +'/'+ random.choice(sorted(os.listdir(path))))
    
    # Display the Selected Image
    plt.imshow(rand_img)
    
    # Add Labels for Image Dimensions
    #width of image
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    
    #height of image
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %% [markdown]
# ## Image Data Augmentation and Generator Setup for Rice Leaf Classification
#
#  1. Setting up the training data generator
#
#  2. Setting up the validation data generator

# %%
# Set up the training data generator using the flow_from_directory method

training_set = train_datagen.flow_from_directory(
       
                                                 # Path to the dataset directory
                                                 r"Data",
                                                 
                                                 # Resize images to 256x256 pixels
                                                 target_size=(256, 256),
                                                 
                                                 # Number of images in each batch
                                                 batch_size=5,
                                                 
                                                 # Use categorical labels
                                                 class_mode='categorical',
                                                 
                                                 # Specify that this is the training set
                                                 subset='training')
# Out:
# Found 90 images belonging to 3 classes.

# %%
# Set up the validation data generator using the flow_from_directory method

validation_set = train_datagen.flow_from_directory(
       
                                                 # Path to the directory containing validation images       
                                                 r"Data",
                                                 
                                                 # Resize images to 256x256 pixels
                                                 target_size=(256, 256),
                                                 
                                                 # Number of images in each batch
                                                 batch_size=5,
                                                 
                                                 # Use categorical labels
                                                 class_mode='categorical',
                                                 
                                                 # Specify that this is the validation set
                                                 subset='validation')
# Out:
# Found 29 images belonging to 3 classes.

# %% [markdown]
# ## Building Convolution Neural Network

# %% [markdown]
# ### Convolution Neural Network (CNN)
#
# CNN stands for Convolution Neural Network. It is a type of artificial neural network specifically designed for processing and analyzing visual data. CNNs are widely used in computer vision tasks, such as image recognition, object detection, and image classification.
#
#
# 1. Input Layer:
#
#     The input to a CNN is usually an image, although it can be extended to other types of data.
#     Images are represented as a grid of pixel values, and each pixel represents the intensity of light at that point.
#
#
#
# 2. Convolutional Layers:
#
#     The convolutional layers are the core building blocks of a CNN.
#     Convolution involves applying filters or kernels to the input data to extract local patterns or features. These filters slide over the input in small regions, performing element-wise multiplication and summing the results.
#     Convolution helps capture spatial hierarchies and patterns in the input data.
#
#
#
# 3. Activation Function:
#
#     After convolution, an activation function (commonly ReLU - Rectified Linear Unit) is applied element-wise to introduce non-linearity, allowing the network to learn complex relationships.
#
#
#
# 4. Pooling (Subsampling) Layers:
#
#     Pooling layers follow convolutional layers to reduce spatial dimensions.
#     Common pooling operations include max pooling or average pooling, where the maximum or average value within a region is taken, respectively.
#     Pooling helps in reducing computation and makes the network more robust to variations in input.
#
#
#
# 5. Flattening:
#
#     After several convolutional and pooling layers, the data is flattened into a vector. This vector is then used as the input for fully connected layers.
#
#
#
# 6. Fully Connected Layers:
#
#     Fully connected layers are traditional neural network layers where each neuron is connected to every neuron in the previous and next layers.
#     These layers integrate high-level features from the convolutional layers and make the final predictions.
#     The output of the last fully connected layer is often processed by a softmax activation function for classification tasks, providing probability scores for each class.
#
#
#
# 7. Output Layer:
#
#     The output layer produces the final predictions based on the information learned through the network.
#     For classification tasks, the output layer often uses softmax activation to generate class probabilities.

# %% [markdown]
# ### Building the models with respect to the optimizer
#
#
# Optimizers are algorithms or methods used to minimize the loss function during the training of a neural network. They play a crucial role in updating the model's parameters (weights and biases) to improve its performance. Here are some common optimizers used in deep learning:

# %% [markdown]
# ### 1. Using Stochastic Gradient Descent

# %%
# using stochastic gradient descent


#Initialising the CNN model
model_sgd = Sequential()


# First Convolution Layer
model_sgd.add(Conv2D(filters= 16, kernel_size=2, activation='relu', input_shape=[256, 256, 3]))


# First Pooling Layer
model_sgd.add(MaxPooling2D(pool_size=2))


# Second Convolution Layer
model_sgd.add(Conv2D(filters=32, kernel_size=2, activation='relu'))


# Second Pooling Layer
model_sgd.add(MaxPooling2D(pool_size=2))


# Third Convolution Layer
model_sgd.add(Conv2D(filters=32, kernel_size=2, activation='relu'))


# Third Pooling Layer
model_sgd.add(MaxPooling2D(pool_size=2))


# Fourth Convolution Layer.
model_sgd.add(Conv2D(filters=64, kernel_size=2, activation='relu'))


# Fourth Pooling Layer
model_sgd.add(MaxPooling2D(pool_size=2))


# Flattening
model_sgd.add(Flatten())


# Fully Connected Layer
model_sgd.add(Dense(128, activation="relu"))


# Output Layer
model_sgd.add(Dense(3, activation="softmax"))

# %%
# Display a summary of the model architecture and parameters
model_sgd.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 255, 255, 16)   │           208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 126, 126, 32)   │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 62, 62, 32)     │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 31, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 30, 30, 64)     │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 15, 15, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 14400)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,843,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,858,387 (7.09 MB)
#  Trainable params: 1,858,387 (7.09 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Compiling and Training the model

# %%
# Import the Stochastic Gradient Descent (SGD) optimizer from Keras
from keras.optimizers import SGD


# Compile the model using categorical cross-entropy as the loss function,
# SGD as the optimizer, and accuracy as the evaluation metric
model_sgd.compile(loss = 'categorical_crossentropy',  optimizer = "sgd", metrics=['accuracy'])

# Train the model using the fit_generator function
history_sgd = model_sgd.fit(
                                        # Training data generator
                                        training_set,
                                        
                                        # Number of steps (batches) to yield from the generator for each epoch
                                        steps_per_epoch=len(training_set),
                                        
                                        # Number of epochs to train the model
                                        epochs=150,
                                        
                                        # Validation data generator
                                        validation_data=validation_set,
                                        
                                        # Number of steps (batches) to yield from the generator for each epoch during validation
                                        validation_steps = len(validation_set))
# Out:
# Epoch 1/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 476ms/step - accuracy: 0.3110 - loss: 1.1004 - val_accuracy: 0.3448 - val_loss: 1.0961
# Epoch 2/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 368ms/step - accuracy: 0.3322 - loss: 1.0986 - val_accuracy: 0.4828 - val_loss: 1.0965
# Epoch 3/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 372ms/step - accuracy: 0.4426 - loss: 1.0990 - val_accuracy: 0.5172 - val_loss: 1.0942
# Epoch 4/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 371ms/step - accuracy: 0.4683 - loss: 1.0956 - val_accuracy: 0.5862 - val_loss: 1.0929
# Epoch 5/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 361ms/step - accuracy: 0.2764 - loss: 1.0974 - val_accuracy: 0.3793 - val_loss: 1.0948
# Epoch 6/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 371ms/step - accuracy: 0.3378 - loss: 1.0969 - val_accuracy: 0.4138 - val_loss: 1.0932
# Epoch 7/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 373ms/step - accuracy: 0.3795 - loss: 1.0994 - val_accuracy: 0.4483 - val_loss: 1.0955
# Epoch 8/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 367ms/step - accuracy: 0.3530 - loss: 1.0978 - val_accuracy: 0.5517 - val_loss: 1.0933
# Epoch 9/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 377ms/step - accuracy: 0.4458 - loss: 1.0922 - val_accuracy: 0.4483 - val_loss: 1.0939
# Epoch 10/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 360ms/step - accuracy: 0.4394 - loss: 1.0948 - val_accuracy: 0.5172 - val_loss: 1.0921
# Epoch 11/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.4207 - loss: 1.0969 - val_accuracy: 0.4483 - val_loss: 1.0933
# Epoch 12/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 384ms/step - accuracy: 0.3356 - loss: 1.0956 - val_accuracy: 0.5862 - val_loss: 1.0903
# Epoch 13/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 361ms/step - accuracy: 0.4872 - loss: 1.0845 - val_accuracy: 0.4483 - val_loss: 1.0901
# Epoch 14/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 357ms/step - accuracy: 0.3554 - loss: 1.0961 - val_accuracy: 0.4828 - val_loss: 1.0902
# Epoch 15/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 362ms/step - accuracy: 0.4033 - loss: 1.0969 - val_accuracy: 0.4828 - val_loss: 1.0867
# Epoch 16/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 384ms/step - accuracy: 0.4304 - loss: 1.0893 - val_accuracy: 0.3448 - val_loss: 1.0900
# Epoch 17/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 447ms/step - accuracy: 0.3959 - loss: 1.0855 - val_accuracy: 0.3448 - val_loss: 1.0930
# Epoch 18/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 389ms/step - accuracy: 0.4222 - loss: 1.0854 - val_accuracy: 0.5172 - val_loss: 1.0831
# Epoch 19/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 391ms/step - accuracy: 0.4590 - loss: 1.0894 - val_accuracy: 0.3448 - val_loss: 1.0901
# Epoch 20/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 369ms/step - accuracy: 0.3372 - loss: 1.0926 - val_accuracy: 0.4828 - val_loss: 1.0845
# Epoch 21/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.3120 - loss: 1.0929 - val_accuracy: 0.5172 - val_loss: 1.0870
# Epoch 22/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 361ms/step - accuracy: 0.3881 - loss: 1.0845 - val_accuracy: 0.3448 - val_loss: 1.0937
# Epoch 23/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 369ms/step - accuracy: 0.3430 - loss: 1.0911 - val_accuracy: 0.3448 - val_loss: 1.0808
# Epoch 24/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 351ms/step - accuracy: 0.3865 - loss: 1.0711 - val_accuracy: 0.4138 - val_loss: 1.0798
# Epoch 25/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 376ms/step - accuracy: 0.5374 - loss: 1.0786 - val_accuracy: 0.5172 - val_loss: 1.0818
# Epoch 26/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 359ms/step - accuracy: 0.4319 - loss: 1.0758 - val_accuracy: 0.3103 - val_loss: 1.1064
# Epoch 27/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 355ms/step - accuracy: 0.3498 - loss: 1.0815 - val_accuracy: 0.5862 - val_loss: 1.0588
# Epoch 28/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 361ms/step - accuracy: 0.4342 - loss: 1.0762 - val_accuracy: 0.3448 - val_loss: 1.0764
# Epoch 29/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 382ms/step - accuracy: 0.4622 - loss: 1.0663 - val_accuracy: 0.3103 - val_loss: 1.0727
# Epoch 30/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 346ms/step - accuracy: 0.4087 - loss: 1.0887 - val_accuracy: 0.6552 - val_loss: 1.0405
# Epoch 31/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 367ms/step - accuracy: 0.3383 - loss: 1.0424 - val_accuracy: 0.5172 - val_loss: 1.0412
# Epoch 32/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 371ms/step - accuracy: 0.4631 - loss: 1.0561 - val_accuracy: 0.4828 - val_loss: 1.0382
# Epoch 33/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 370ms/step - accuracy: 0.4169 - loss: 1.0567 - val_accuracy: 0.6552 - val_loss: 1.0289
# Epoch 34/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 377ms/step - accuracy: 0.4625 - loss: 1.0449 - val_accuracy: 0.6207 - val_loss: 1.0274
# Epoch 35/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 372ms/step - accuracy: 0.4678 - loss: 1.0348 - val_accuracy: 0.4483 - val_loss: 1.0178
# Epoch 36/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 373ms/step - accuracy: 0.5097 - loss: 1.0054 - val_accuracy: 0.3448 - val_loss: 1.0894
# Epoch 37/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 353ms/step - accuracy: 0.4024 - loss: 1.0481 - val_accuracy: 0.3103 - val_loss: 1.1214
# Epoch 38/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 354ms/step - accuracy: 0.4493 - loss: 1.0156 - val_accuracy: 0.6207 - val_loss: 0.9922
# Epoch 39/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.4615 - loss: 1.0187 - val_accuracy: 0.3103 - val_loss: 1.1674
# Epoch 40/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 372ms/step - accuracy: 0.3989 - loss: 1.0926 - val_accuracy: 0.5862 - val_loss: 0.9772
# Epoch 41/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 362ms/step - accuracy: 0.4572 - loss: 1.0456 - val_accuracy: 0.6552 - val_loss: 0.9723
# Epoch 42/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 368ms/step - accuracy: 0.4852 - loss: 1.0031 - val_accuracy: 0.6207 - val_loss: 0.9563
# Epoch 43/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 363ms/step - accuracy: 0.5087 - loss: 0.9948 - val_accuracy: 0.6897 - val_loss: 0.9175
# Epoch 44/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 360ms/step - accuracy: 0.4961 - loss: 1.0095 - val_accuracy: 0.5517 - val_loss: 0.9740
# Epoch 45/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 357ms/step - accuracy: 0.3065 - loss: 1.0047 - val_accuracy: 0.5172 - val_loss: 0.9814
# Epoch 46/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 352ms/step - accuracy: 0.4795 - loss: 0.9689 - val_accuracy: 0.6552 - val_loss: 0.9492
# Epoch 47/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 356ms/step - accuracy: 0.4848 - loss: 0.9820 - val_accuracy: 0.5517 - val_loss: 0.9108
# Epoch 48/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 353ms/step - accuracy: 0.5527 - loss: 0.9117 - val_accuracy: 0.7931 - val_loss: 0.8021
# Epoch 49/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 368ms/step - accuracy: 0.5202 - loss: 0.9237 - val_accuracy: 0.6207 - val_loss: 0.9401
# Epoch 50/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 348ms/step - accuracy: 0.6287 - loss: 0.8951 - val_accuracy: 0.5862 - val_loss: 0.9098
# Epoch 51/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 341ms/step - accuracy: 0.4733 - loss: 1.0353 - val_accuracy: 0.4828 - val_loss: 0.8979
# Epoch 52/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 358ms/step - accuracy: 0.5189 - loss: 0.8645 - val_accuracy: 0.3793 - val_loss: 1.2792
# Epoch 53/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 355ms/step - accuracy: 0.3990 - loss: 1.0471 - val_accuracy: 0.5862 - val_loss: 0.8449
# Epoch 54/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 355ms/step - accuracy: 0.5817 - loss: 0.9441 - val_accuracy: 0.6552 - val_loss: 0.8358
# Epoch 55/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 343ms/step - accuracy: 0.5208 - loss: 0.9231 - val_accuracy: 0.6552 - val_loss: 0.8975
# Epoch 56/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 364ms/step - accuracy: 0.5507 - loss: 0.8650 - val_accuracy: 0.5517 - val_loss: 0.9111
# Epoch 57/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 356ms/step - accuracy: 0.5527 - loss: 0.9356 - val_accuracy: 0.5172 - val_loss: 0.9628
# Epoch 58/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 350ms/step - accuracy: 0.5113 - loss: 0.9962 - val_accuracy: 0.6552 - val_loss: 0.8841
# Epoch 59/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 373ms/step - accuracy: 0.5741 - loss: 0.8926 - val_accuracy: 0.6552 - val_loss: 0.8121
# Epoch 60/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 356ms/step - accuracy: 0.4957 - loss: 0.8960 - val_accuracy: 0.5172 - val_loss: 1.0558
# Epoch 61/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 346ms/step - accuracy: 0.5417 - loss: 0.9315 - val_accuracy: 0.6207 - val_loss: 0.7808
# Epoch 62/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 354ms/step - accuracy: 0.5473 - loss: 0.8918 - val_accuracy: 0.6207 - val_loss: 0.9057
# Epoch 63/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 363ms/step - accuracy: 0.5979 - loss: 0.8597 - val_accuracy: 0.7241 - val_loss: 0.8360
# Epoch 64/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 351ms/step - accuracy: 0.6022 - loss: 0.8466 - val_accuracy: 0.6897 - val_loss: 0.8037
# Epoch 65/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 345ms/step - accuracy: 0.5599 - loss: 0.9056 - val_accuracy: 0.6552 - val_loss: 0.8843
# Epoch 66/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 347ms/step - accuracy: 0.6160 - loss: 0.8453 - val_accuracy: 0.5517 - val_loss: 0.8373
# Epoch 67/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 351ms/step - accuracy: 0.5741 - loss: 0.9264 - val_accuracy: 0.5862 - val_loss: 0.8998
# Epoch 68/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 348ms/step - accuracy: 0.4897 - loss: 0.8998 - val_accuracy: 0.7241 - val_loss: 0.7758
# Epoch 69/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 355ms/step - accuracy: 0.5346 - loss: 0.9002 - val_accuracy: 0.6207 - val_loss: 0.7890
# Epoch 70/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 365ms/step - accuracy: 0.6151 - loss: 0.8449 - val_accuracy: 0.6897 - val_loss: 0.8708
# Epoch 71/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 351ms/step - accuracy: 0.6397 - loss: 0.8188 - val_accuracy: 0.8621 - val_loss: 0.7262
# Epoch 72/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 351ms/step - accuracy: 0.6141 - loss: 0.8207 - val_accuracy: 0.7586 - val_loss: 0.7000
# Epoch 73/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 367ms/step - accuracy: 0.5215 - loss: 0.8667 - val_accuracy: 0.5517 - val_loss: 1.0614
# Epoch 74/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 354ms/step - accuracy: 0.4241 - loss: 0.9891 - val_accuracy: 0.6207 - val_loss: 0.8803
# Epoch 75/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 348ms/step - accuracy: 0.5508 - loss: 0.8606 - val_accuracy: 0.5517 - val_loss: 0.9938
# Epoch 76/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 379ms/step - accuracy: 0.6198 - loss: 0.8903 - val_accuracy: 0.8276 - val_loss: 0.6941
# Epoch 77/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 364ms/step - accuracy: 0.6965 - loss: 0.6788 - val_accuracy: 0.5517 - val_loss: 0.8034
# Epoch 78/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 352ms/step - accuracy: 0.4991 - loss: 0.9690 - val_accuracy: 0.6897 - val_loss: 0.7192
# Epoch 79/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 364ms/step - accuracy: 0.6133 - loss: 0.7905 - val_accuracy: 0.5862 - val_loss: 0.7859
# Epoch 80/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 369ms/step - accuracy: 0.6218 - loss: 0.8734 - val_accuracy: 0.5517 - val_loss: 0.7596
# Epoch 81/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 355ms/step - accuracy: 0.6275 - loss: 0.8276 - val_accuracy: 0.5862 - val_loss: 0.6439
# Epoch 82/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 363ms/step - accuracy: 0.6281 - loss: 0.8118 - val_accuracy: 0.7586 - val_loss: 0.6626
# Epoch 83/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 361ms/step - accuracy: 0.5078 - loss: 0.9689 - val_accuracy: 0.5862 - val_loss: 0.7858
# Epoch 84/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 369ms/step - accuracy: 0.5812 - loss: 0.8278 - val_accuracy: 0.7586 - val_loss: 0.7688
# Epoch 85/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 373ms/step - accuracy: 0.6710 - loss: 0.8339 - val_accuracy: 0.7241 - val_loss: 0.6625
# Epoch 86/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 365ms/step - accuracy: 0.7311 - loss: 0.7122 - val_accuracy: 0.8621 - val_loss: 0.6968
# Epoch 87/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 348ms/step - accuracy: 0.6852 - loss: 0.8114 - val_accuracy: 0.5172 - val_loss: 1.0336
# Epoch 88/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.5795 - loss: 0.8725 - val_accuracy: 0.3103 - val_loss: 1.2335
# Epoch 89/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 364ms/step - accuracy: 0.6985 - loss: 0.8222 - val_accuracy: 0.7586 - val_loss: 0.7954
# Epoch 90/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 379ms/step - accuracy: 0.7398 - loss: 0.7092 - val_accuracy: 0.7241 - val_loss: 0.7034
# Epoch 91/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 370ms/step - accuracy: 0.7093 - loss: 0.7173 - val_accuracy: 0.6897 - val_loss: 0.8263
# Epoch 92/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 374ms/step - accuracy: 0.5739 - loss: 0.7571 - val_accuracy: 0.4483 - val_loss: 1.2579
# Epoch 93/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 367ms/step - accuracy: 0.6345 - loss: 0.8597 - val_accuracy: 0.8621 - val_loss: 0.6205
# Epoch 94/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.6276 - loss: 0.7981 - val_accuracy: 0.6207 - val_loss: 0.7192
# Epoch 95/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 364ms/step - accuracy: 0.5945 - loss: 0.7913 - val_accuracy: 0.7241 - val_loss: 0.7086
# Epoch 96/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 357ms/step - accuracy: 0.6818 - loss: 0.7135 - val_accuracy: 0.3793 - val_loss: 1.3029
# Epoch 97/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 348ms/step - accuracy: 0.5599 - loss: 0.9240 - val_accuracy: 0.7586 - val_loss: 0.6695
# Epoch 98/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 358ms/step - accuracy: 0.7411 - loss: 0.6922 - val_accuracy: 0.7931 - val_loss: 0.6823
# Epoch 99/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 377ms/step - accuracy: 0.6310 - loss: 0.7789 - val_accuracy: 0.6897 - val_loss: 0.6599
# Epoch 100/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 356ms/step - accuracy: 0.6981 - loss: 0.7165 - val_accuracy: 0.8621 - val_loss: 0.5836
# Epoch 101/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 360ms/step - accuracy: 0.7005 - loss: 0.6721 - val_accuracy: 0.7241 - val_loss: 0.7889
# Epoch 102/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 356ms/step - accuracy: 0.7449 - loss: 0.6233 - val_accuracy: 0.7241 - val_loss: 0.6946
# Epoch 103/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 354ms/step - accuracy: 0.6664 - loss: 0.7306 - val_accuracy: 0.6207 - val_loss: 0.7424
# Epoch 104/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 358ms/step - accuracy: 0.7233 - loss: 0.7398 - val_accuracy: 0.8276 - val_loss: 0.5868
# Epoch 105/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 359ms/step - accuracy: 0.7264 - loss: 0.6990 - val_accuracy: 0.7931 - val_loss: 0.5389
# Epoch 106/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 367ms/step - accuracy: 0.7430 - loss: 0.6319 - val_accuracy: 0.5862 - val_loss: 0.9013
# Epoch 107/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 357ms/step - accuracy: 0.7091 - loss: 0.5870 - val_accuracy: 0.8276 - val_loss: 0.5891
# Epoch 108/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.6894 - loss: 0.6873 - val_accuracy: 0.7586 - val_loss: 0.7342
# Epoch 109/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 370ms/step - accuracy: 0.7005 - loss: 0.5727 - val_accuracy: 0.7931 - val_loss: 0.9244
# Epoch 110/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.7157 - loss: 0.6344 - val_accuracy: 0.7241 - val_loss: 0.6210
# Epoch 111/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 364ms/step - accuracy: 0.7912 - loss: 0.5498 - val_accuracy: 0.8276 - val_loss: 0.4924
# Epoch 112/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 361ms/step - accuracy: 0.7818 - loss: 0.6008 - val_accuracy: 0.7931 - val_loss: 0.7083
# Epoch 113/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 359ms/step - accuracy: 0.7058 - loss: 0.6631 - val_accuracy: 0.6897 - val_loss: 0.6879
# Epoch 114/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 358ms/step - accuracy: 0.7608 - loss: 0.5940 - val_accuracy: 0.8276 - val_loss: 0.5269
# Epoch 115/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 367ms/step - accuracy: 0.6811 - loss: 0.6911 - val_accuracy: 0.6897 - val_loss: 0.6176
# Epoch 116/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 356ms/step - accuracy: 0.7741 - loss: 0.6721 - val_accuracy: 0.7241 - val_loss: 0.5838
# Epoch 117/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 383ms/step - accuracy: 0.7905 - loss: 0.5718 - val_accuracy: 0.7931 - val_loss: 0.6594
# Epoch 118/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 371ms/step - accuracy: 0.7310 - loss: 0.5138 - val_accuracy: 0.7931 - val_loss: 0.5514
# Epoch 119/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 361ms/step - accuracy: 0.8207 - loss: 0.5487 - val_accuracy: 0.8621 - val_loss: 0.6227
# Epoch 120/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 461ms/step - accuracy: 0.7868 - loss: 0.6592 - val_accuracy: 0.4828 - val_loss: 2.2376
# Epoch 121/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 437ms/step - accuracy: 0.4797 - loss: 1.5369 - val_accuracy: 0.7931 - val_loss: 0.6931
# Epoch 122/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 368ms/step - accuracy: 0.8189 - loss: 0.5208 - val_accuracy: 0.7586 - val_loss: 0.6632
# Epoch 123/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 341ms/step - accuracy: 0.7822 - loss: 0.5880 - val_accuracy: 0.6897 - val_loss: 0.5265
# Epoch 124/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 347ms/step - accuracy: 0.7730 - loss: 0.5698 - val_accuracy: 0.7241 - val_loss: 0.6298
# Epoch 125/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 349ms/step - accuracy: 0.8212 - loss: 0.5393 - val_accuracy: 0.8276 - val_loss: 0.5615
# Epoch 126/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 353ms/step - accuracy: 0.7623 - loss: 0.5384 - val_accuracy: 0.7931 - val_loss: 0.5694
# Epoch 127/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 343ms/step - accuracy: 0.7502 - loss: 0.5781 - val_accuracy: 0.8621 - val_loss: 0.5496
# Epoch 128/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 357ms/step - accuracy: 0.6889 - loss: 0.6258 - val_accuracy: 0.7241 - val_loss: 0.6758
# Epoch 129/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 344ms/step - accuracy: 0.7535 - loss: 0.5600 - val_accuracy: 0.8621 - val_loss: 0.4442
# Epoch 130/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 362ms/step - accuracy: 0.7952 - loss: 0.5003 - val_accuracy: 0.6897 - val_loss: 0.6907
# Epoch 131/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 351ms/step - accuracy: 0.7168 - loss: 0.6105 - val_accuracy: 0.7586 - val_loss: 0.5562
# Epoch 132/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 339ms/step - accuracy: 0.8375 - loss: 0.5068 - val_accuracy: 0.6207 - val_loss: 0.7968
# Epoch 133/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 332ms/step - accuracy: 0.6857 - loss: 0.6198 - val_accuracy: 0.6207 - val_loss: 0.6492
# Epoch 134/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 356ms/step - accuracy: 0.5516 - loss: 1.1656 - val_accuracy: 0.8621 - val_loss: 0.6700
# Epoch 135/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 355ms/step - accuracy: 0.7310 - loss: 0.6091 - val_accuracy: 0.8966 - val_loss: 0.5718
# Epoch 136/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 362ms/step - accuracy: 0.7435 - loss: 0.6191 - val_accuracy: 0.8966 - val_loss: 0.5791
# Epoch 137/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 337ms/step - accuracy: 0.7028 - loss: 0.6082 - val_accuracy: 0.7586 - val_loss: 0.7429
# Epoch 138/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 353ms/step - accuracy: 0.7524 - loss: 0.5049 - val_accuracy: 0.6552 - val_loss: 0.6804
# Epoch 139/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 355ms/step - accuracy: 0.6718 - loss: 0.7579 - val_accuracy: 0.7241 - val_loss: 0.8322
# Epoch 140/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 356ms/step - accuracy: 0.7123 - loss: 0.6364 - val_accuracy: 0.6207 - val_loss: 0.6799
# Epoch 141/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 371ms/step - accuracy: 0.8371 - loss: 0.4702 - val_accuracy: 0.7931 - val_loss: 0.5380
# Epoch 142/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 353ms/step - accuracy: 0.8586 - loss: 0.4672 - val_accuracy: 0.6552 - val_loss: 0.7179
# Epoch 143/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 355ms/step - accuracy: 0.8323 - loss: 0.4650 - val_accuracy: 0.7586 - val_loss: 0.5543
# Epoch 144/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 360ms/step - accuracy: 0.7190 - loss: 0.6047 - val_accuracy: 0.6207 - val_loss: 0.9638
# Epoch 145/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 369ms/step - accuracy: 0.8182 - loss: 0.4229 - val_accuracy: 0.6897 - val_loss: 0.6573
# Epoch 146/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 361ms/step - accuracy: 0.7511 - loss: 0.5161 - val_accuracy: 0.8621 - val_loss: 0.5907
# Epoch 147/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 357ms/step - accuracy: 0.8243 - loss: 0.4490 - val_accuracy: 0.8276 - val_loss: 0.6628
# Epoch 148/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 367ms/step - accuracy: 0.7929 - loss: 0.5118 - val_accuracy: 0.8276 - val_loss: 0.4529
# Epoch 149/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 359ms/step - accuracy: 0.7916 - loss: 0.5179 - val_accuracy: 0.6207 - val_loss: 0.8426
# Epoch 150/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 370ms/step - accuracy: 0.7652 - loss: 0.4196 - val_accuracy: 0.6552 - val_loss: 0.7653

# %%
# Access the keys of the training history dictionary
history_sgd.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %% [markdown]
# #### Model Accuracy

# %%
# Evaluate the CNN model on the validation set using the SGD optimizer
score_sgd = model_sgd.evaluate(validation_set,verbose=0)

# Extract the accuracy from the evaluation score
accuracy_sgd = 100*score_sgd[1]

# Print the accuracy of the CNN model with the SGD optimizer
print('Accuracy CNN Model with SGD Optimizer',accuracy_sgd)
# Out:
# Accuracy CNN Model with SGD Optimizer 58.62069129943848

# %%
# Set the size of the figure (width=12, height=7)
plt.figure(figsize=(12,7))

# Set the label for the x-axis
plt.xlabel('Epoch Number',fontsize=15)

# Set the label for the y-axis
plt.ylabel('Accuracy',fontsize=15)

# Plot the training accuracy over epochs
plt.plot(history_sgd.history['accuracy'], label = 'training set')

# Plot the validation accuracy over epochs
plt.plot(history_sgd.history['val_accuracy'], label = 'validation set')

# Add a legend to the plot to distinguish between training and validation sets
plt.legend()

# Set the title of the plot
plt.title("Model Accuracy with SGD Optimizer",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Model Accuracy with SGD Optimizer')

# %% [markdown]
# #### Model Loss

# %%
# Set the figure size for the plot
plt.figure(figsize=(12,7))

# Set the x-axis label
plt.xlabel('Epoch Number',fontsize=15)

# Set the y-axis label
plt.ylabel('Loss',fontsize=15)

# Plot the training loss curve
plt.plot(history_sgd.history['loss'], label = 'training set')

# Plot the validation loss curve
plt.plot(history_sgd.history['val_loss'], label = 'validation set')

# Display a legend to distinguish between the training and validation curves
plt.legend()

# Set the title of the plot
plt.title("Model Loss with SGD Optimizer",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Model Loss with SGD Optimizer')

# %% [markdown]
# ### 2. Using ADAM Optimizer

# %%
# using ADAM optimizer

# Initializing the CNN model
model_adam = Sequential()

# First Convolution Layer
model_adam.add(Conv2D(filters= 16, kernel_size=2, activation='relu', input_shape=[256, 256, 3]))

# First Pooling Layer
model_adam.add(MaxPooling2D(pool_size=2))

# Second Convolution Layer
model_adam.add(Conv2D(filters=32, kernel_size=2, activation='relu'))

# Second Pooling Layer
model_adam.add(MaxPooling2D(pool_size=2))

# Third Convolution Layer
model_adam.add(Conv2D(filters=32, kernel_size=2, activation='relu'))

# Third Pooling Layer
model_adam.add(MaxPooling2D(pool_size=2))

# Fourth Convolution Layer.
model_adam.add(Conv2D(filters=64, kernel_size=2, activation='relu'))

# Fourth Pooling Layer
model_adam.add(MaxPooling2D(pool_size=2))

# Flattening
model_adam.add(Flatten())

# Fully Connected Layer
model_adam.add(Dense(128, activation="relu"))

# Deactivating 50% of neuron
model_adam.add(Dropout(0.5))

# Output Layer
model_adam.add(Dense(3, activation="softmax"))

# %%
# Display a summary of the model architecture and parameters
model_adam.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 255, 255, 16)   │           208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 127, 127, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 126, 126, 32)   │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 62, 62, 32)     │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 31, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 30, 30, 64)     │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 15, 15, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 14400)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │     1,843,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,858,387 (7.09 MB)
#  Trainable params: 1,858,387 (7.09 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Compiling and training the model

# %%
from keras.optimizers import Adam

# Compile the neural network model with the specified configuration
model_adam.compile(
                    # Use categorical cross-entropy as the loss function for multi-class classification
                    loss = 'categorical_crossentropy', 
                    
                    # Use the Adam optimizer for gradient descent
                    optimizer = 'adam', 
                    
                    # Monitor and report accuracy as a metric during training
                    metrics=['accuracy'])


# Train the compiled model using the fit_generator method
history_adam = model_adam.fit(
                                            # Training data generator
                                            training_set,
                                            
                                            # Number of batches to process from the generator in each epoch
                                            steps_per_epoch=len(training_set),
                                            
                                            # Number of epochs to train the model
                                            epochs=150,
                                            
                                            # Validation data generator to evaluate the model's performance on a separate dataset
                                            validation_data=validation_set,
                                            
                                            # Number of batches to process from the validation generator in each epoch
                                            validation_steps = len(validation_set))
# Out:
# Epoch 1/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 13s 455ms/step - accuracy: 0.3436 - loss: 1.2332 - val_accuracy: 0.3448 - val_loss: 1.1031
# Epoch 2/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 370ms/step - accuracy: 0.3892 - loss: 1.1087 - val_accuracy: 0.3448 - val_loss: 1.0968
# Epoch 3/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 372ms/step - accuracy: 0.3388 - loss: 1.1015 - val_accuracy: 0.3103 - val_loss: 1.0975
# Epoch 4/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 376ms/step - accuracy: 0.2960 - loss: 1.0969 - val_accuracy: 0.3103 - val_loss: 1.0979
# Epoch 5/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 370ms/step - accuracy: 0.3765 - loss: 1.1009 - val_accuracy: 0.3103 - val_loss: 1.0993
# Epoch 6/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 383ms/step - accuracy: 0.3840 - loss: 1.0964 - val_accuracy: 0.3103 - val_loss: 1.1037
# Epoch 7/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 394ms/step - accuracy: 0.3057 - loss: 1.0861 - val_accuracy: 0.3103 - val_loss: 1.2225
# Epoch 8/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 383ms/step - accuracy: 0.3756 - loss: 1.0517 - val_accuracy: 0.3448 - val_loss: 1.1119
# Epoch 9/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 396ms/step - accuracy: 0.4156 - loss: 1.0138 - val_accuracy: 0.3103 - val_loss: 1.1093
# Epoch 10/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 383ms/step - accuracy: 0.3759 - loss: 1.0577 - val_accuracy: 0.3448 - val_loss: 1.1079
# Epoch 11/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 375ms/step - accuracy: 0.4453 - loss: 1.0452 - val_accuracy: 0.3448 - val_loss: 1.1516
# Epoch 12/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 386ms/step - accuracy: 0.4406 - loss: 1.0149 - val_accuracy: 0.2759 - val_loss: 1.2443
# Epoch 13/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 382ms/step - accuracy: 0.3611 - loss: 1.0416 - val_accuracy: 0.1724 - val_loss: 1.4082
# Epoch 14/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 381ms/step - accuracy: 0.4308 - loss: 1.0007 - val_accuracy: 0.2069 - val_loss: 1.4474
# Epoch 15/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 392ms/step - accuracy: 0.4064 - loss: 1.0732 - val_accuracy: 0.3793 - val_loss: 1.2980
# Epoch 16/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 396ms/step - accuracy: 0.4605 - loss: 1.0382 - val_accuracy: 0.3448 - val_loss: 1.1771
# Epoch 17/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 399ms/step - accuracy: 0.3308 - loss: 1.0241 - val_accuracy: 0.3103 - val_loss: 1.3185
# Epoch 18/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 396ms/step - accuracy: 0.4926 - loss: 0.9816 - val_accuracy: 0.3448 - val_loss: 1.3805
# Epoch 19/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 376ms/step - accuracy: 0.4506 - loss: 0.9662 - val_accuracy: 0.2759 - val_loss: 1.2843
# Epoch 20/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 408ms/step - accuracy: 0.4651 - loss: 1.0028 - val_accuracy: 0.2069 - val_loss: 1.4853
# Epoch 21/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 381ms/step - accuracy: 0.4638 - loss: 1.0282 - val_accuracy: 0.2069 - val_loss: 1.4046
# Epoch 22/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 384ms/step - accuracy: 0.4659 - loss: 0.9886 - val_accuracy: 0.2759 - val_loss: 1.3550
# Epoch 23/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 388ms/step - accuracy: 0.5956 - loss: 0.9627 - val_accuracy: 0.2759 - val_loss: 1.3525
# Epoch 24/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 385ms/step - accuracy: 0.4935 - loss: 1.0306 - val_accuracy: 0.2414 - val_loss: 1.3615
# Epoch 25/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 385ms/step - accuracy: 0.3842 - loss: 1.0345 - val_accuracy: 0.3103 - val_loss: 1.7143
# Epoch 26/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 393ms/step - accuracy: 0.4426 - loss: 1.0367 - val_accuracy: 0.2759 - val_loss: 1.2260
# Epoch 27/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 399ms/step - accuracy: 0.4475 - loss: 0.9922 - val_accuracy: 0.3448 - val_loss: 1.5165
# Epoch 28/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 397ms/step - accuracy: 0.5210 - loss: 0.9704 - val_accuracy: 0.2414 - val_loss: 1.8314
# Epoch 29/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 384ms/step - accuracy: 0.5176 - loss: 0.9853 - val_accuracy: 0.3103 - val_loss: 1.3138
# Epoch 30/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 381ms/step - accuracy: 0.4913 - loss: 1.0113 - val_accuracy: 0.3793 - val_loss: 1.4024
# Epoch 31/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 373ms/step - accuracy: 0.4896 - loss: 1.0342 - val_accuracy: 0.2759 - val_loss: 2.2148
# Epoch 32/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 380ms/step - accuracy: 0.4491 - loss: 1.0220 - val_accuracy: 0.2414 - val_loss: 2.0006
# Epoch 33/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 386ms/step - accuracy: 0.5060 - loss: 0.9077 - val_accuracy: 0.2414 - val_loss: 2.3593
# Epoch 34/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 381ms/step - accuracy: 0.3977 - loss: 1.0541 - val_accuracy: 0.3103 - val_loss: 1.6077
# Epoch 35/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 384ms/step - accuracy: 0.5119 - loss: 0.9607 - val_accuracy: 0.2759 - val_loss: 1.8662
# Epoch 36/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 394ms/step - accuracy: 0.4944 - loss: 1.0614 - val_accuracy: 0.4483 - val_loss: 1.5033
# Epoch 37/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 406ms/step - accuracy: 0.5105 - loss: 0.9030 - val_accuracy: 0.4138 - val_loss: 1.3791
# Epoch 38/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 406ms/step - accuracy: 0.4894 - loss: 1.0159 - val_accuracy: 0.2759 - val_loss: 1.6043
# Epoch 39/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 392ms/step - accuracy: 0.5050 - loss: 0.9980 - val_accuracy: 0.2759 - val_loss: 1.4728
# Epoch 40/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 390ms/step - accuracy: 0.5414 - loss: 0.9288 - val_accuracy: 0.3448 - val_loss: 2.2334
# Epoch 41/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 397ms/step - accuracy: 0.4902 - loss: 0.9074 - val_accuracy: 0.2759 - val_loss: 1.9399
# Epoch 42/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 390ms/step - accuracy: 0.5096 - loss: 0.9008 - val_accuracy: 0.3793 - val_loss: 2.0441
# Epoch 43/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 405ms/step - accuracy: 0.5985 - loss: 0.8484 - val_accuracy: 0.4483 - val_loss: 1.7237
# Epoch 44/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 396ms/step - accuracy: 0.6795 - loss: 0.8532 - val_accuracy: 0.4138 - val_loss: 2.5440
# Epoch 45/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 374ms/step - accuracy: 0.6254 - loss: 0.8454 - val_accuracy: 0.4138 - val_loss: 2.1240
# Epoch 46/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 390ms/step - accuracy: 0.5462 - loss: 0.9203 - val_accuracy: 0.3793 - val_loss: 3.1158
# Epoch 47/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 399ms/step - accuracy: 0.4973 - loss: 0.9874 - val_accuracy: 0.5172 - val_loss: 1.1496
# Epoch 48/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 388ms/step - accuracy: 0.5219 - loss: 0.9781 - val_accuracy: 0.4828 - val_loss: 1.3166
# Epoch 49/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 400ms/step - accuracy: 0.6777 - loss: 0.8546 - val_accuracy: 0.3793 - val_loss: 1.2728
# Epoch 50/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 373ms/step - accuracy: 0.4555 - loss: 0.9689 - val_accuracy: 0.4828 - val_loss: 1.1927
# Epoch 51/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 383ms/step - accuracy: 0.5464 - loss: 0.9311 - val_accuracy: 0.5172 - val_loss: 1.2138
# Epoch 52/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 387ms/step - accuracy: 0.6355 - loss: 0.8110 - val_accuracy: 0.4138 - val_loss: 1.7704
# Epoch 53/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 384ms/step - accuracy: 0.6917 - loss: 0.8530 - val_accuracy: 0.5517 - val_loss: 1.5789
# Epoch 54/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 385ms/step - accuracy: 0.6307 - loss: 0.7729 - val_accuracy: 0.4138 - val_loss: 2.6230
# Epoch 55/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 395ms/step - accuracy: 0.6845 - loss: 0.7555 - val_accuracy: 0.4483 - val_loss: 1.6465
# Epoch 56/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 398ms/step - accuracy: 0.5840 - loss: 0.8480 - val_accuracy: 0.3793 - val_loss: 1.9692
# Epoch 57/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 390ms/step - accuracy: 0.7294 - loss: 0.7601 - val_accuracy: 0.4138 - val_loss: 1.5242
# Epoch 58/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 396ms/step - accuracy: 0.6178 - loss: 0.8384 - val_accuracy: 0.5517 - val_loss: 1.2740
# Epoch 59/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 389ms/step - accuracy: 0.5893 - loss: 0.7535 - val_accuracy: 0.4483 - val_loss: 1.6940
# Epoch 60/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 375ms/step - accuracy: 0.7520 - loss: 0.5928 - val_accuracy: 0.5172 - val_loss: 1.3197
# Epoch 61/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 397ms/step - accuracy: 0.7586 - loss: 0.5997 - val_accuracy: 0.5862 - val_loss: 1.1375
# Epoch 62/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 381ms/step - accuracy: 0.5390 - loss: 0.7084 - val_accuracy: 0.4828 - val_loss: 1.6308
# Epoch 63/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 382ms/step - accuracy: 0.6250 - loss: 0.7847 - val_accuracy: 0.5517 - val_loss: 1.9068
# Epoch 64/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 396ms/step - accuracy: 0.7184 - loss: 0.6379 - val_accuracy: 0.5862 - val_loss: 1.5090
# Epoch 65/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 379ms/step - accuracy: 0.7141 - loss: 0.6244 - val_accuracy: 0.5172 - val_loss: 1.7831
# Epoch 66/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 409ms/step - accuracy: 0.7863 - loss: 0.5223 - val_accuracy: 0.5172 - val_loss: 1.9050
# Epoch 67/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 382ms/step - accuracy: 0.7528 - loss: 0.6391 - val_accuracy: 0.5172 - val_loss: 2.2321
# Epoch 68/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 396ms/step - accuracy: 0.7400 - loss: 0.5450 - val_accuracy: 0.5862 - val_loss: 0.9939
# Epoch 69/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 377ms/step - accuracy: 0.5597 - loss: 0.7319 - val_accuracy: 0.6552 - val_loss: 0.7515
# Epoch 70/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 385ms/step - accuracy: 0.6911 - loss: 0.7310 - val_accuracy: 0.6897 - val_loss: 0.8069
# Epoch 71/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 388ms/step - accuracy: 0.8042 - loss: 0.4926 - val_accuracy: 0.5172 - val_loss: 1.1604
# Epoch 72/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 387ms/step - accuracy: 0.6921 - loss: 0.6228 - val_accuracy: 0.6207 - val_loss: 2.3736
# Epoch 73/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 391ms/step - accuracy: 0.7337 - loss: 0.5333 - val_accuracy: 0.5862 - val_loss: 1.4953
# Epoch 74/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 389ms/step - accuracy: 0.7407 - loss: 0.6027 - val_accuracy: 0.6207 - val_loss: 1.1630
# Epoch 75/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 390ms/step - accuracy: 0.7095 - loss: 0.6170 - val_accuracy: 0.5862 - val_loss: 0.7553
# Epoch 76/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 380ms/step - accuracy: 0.6396 - loss: 0.8280 - val_accuracy: 0.6207 - val_loss: 1.0107
# Epoch 77/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 393ms/step - accuracy: 0.7998 - loss: 0.4817 - val_accuracy: 0.8621 - val_loss: 1.9680
# Epoch 78/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 390ms/step - accuracy: 0.7842 - loss: 0.4378 - val_accuracy: 0.5172 - val_loss: 3.6896
# Epoch 79/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 387ms/step - accuracy: 0.8065 - loss: 0.6092 - val_accuracy: 0.7586 - val_loss: 1.2631
# Epoch 80/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 371ms/step - accuracy: 0.6857 - loss: 0.6685 - val_accuracy: 0.6207 - val_loss: 0.8827
# Epoch 81/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 400ms/step - accuracy: 0.7288 - loss: 0.5303 - val_accuracy: 0.5862 - val_loss: 1.2152
# Epoch 82/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 401ms/step - accuracy: 0.6544 - loss: 0.5814 - val_accuracy: 0.5862 - val_loss: 2.4943
# Epoch 83/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 387ms/step - accuracy: 0.6487 - loss: 0.7140 - val_accuracy: 0.7931 - val_loss: 1.2488
# Epoch 84/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 404ms/step - accuracy: 0.7616 - loss: 0.5332 - val_accuracy: 0.5172 - val_loss: 1.1033
# Epoch 85/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 441ms/step - accuracy: 0.7574 - loss: 0.5461 - val_accuracy: 0.6897 - val_loss: 1.2417
# Epoch 86/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 417ms/step - accuracy: 0.7980 - loss: 0.5030 - val_accuracy: 0.6897 - val_loss: 2.2194
# Epoch 87/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 364ms/step - accuracy: 0.6904 - loss: 0.4907 - val_accuracy: 0.6552 - val_loss: 1.1359
# Epoch 88/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 372ms/step - accuracy: 0.8252 - loss: 0.4233 - val_accuracy: 0.7931 - val_loss: 1.5857
# Epoch 89/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 371ms/step - accuracy: 0.8808 - loss: 0.3023 - val_accuracy: 0.8276 - val_loss: 0.9441
# Epoch 90/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 398ms/step - accuracy: 0.9051 - loss: 0.3091 - val_accuracy: 0.7931 - val_loss: 1.1638
# Epoch 91/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 343ms/step - accuracy: 0.7947 - loss: 0.4517 - val_accuracy: 0.7931 - val_loss: 1.5334
# Epoch 92/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 349ms/step - accuracy: 0.7929 - loss: 0.4215 - val_accuracy: 0.7931 - val_loss: 2.9868
# Epoch 93/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 336ms/step - accuracy: 0.8197 - loss: 0.4277 - val_accuracy: 0.8276 - val_loss: 0.8616
# Epoch 94/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 355ms/step - accuracy: 0.8259 - loss: 0.3252 - val_accuracy: 0.8276 - val_loss: 1.0230
# Epoch 95/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 344ms/step - accuracy: 0.8519 - loss: 0.3710 - val_accuracy: 0.6552 - val_loss: 1.2921
# Epoch 96/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 342ms/step - accuracy: 0.8434 - loss: 0.3082 - val_accuracy: 0.7586 - val_loss: 1.4549
# Epoch 97/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 347ms/step - accuracy: 0.8470 - loss: 0.4150 - val_accuracy: 0.8621 - val_loss: 1.5578
# Epoch 98/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 336ms/step - accuracy: 0.8491 - loss: 0.4347 - val_accuracy: 0.7586 - val_loss: 1.4075
# Epoch 99/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 350ms/step - accuracy: 0.7748 - loss: 0.4764 - val_accuracy: 0.7931 - val_loss: 1.6698
# Epoch 100/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 335ms/step - accuracy: 0.7750 - loss: 0.4109 - val_accuracy: 0.6207 - val_loss: 1.7375
# Epoch 101/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 342ms/step - accuracy: 0.7880 - loss: 0.7175 - val_accuracy: 0.5862 - val_loss: 1.8522
# Epoch 102/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 342ms/step - accuracy: 0.7557 - loss: 0.5994 - val_accuracy: 0.6207 - val_loss: 2.5404
# Epoch 103/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 348ms/step - accuracy: 0.8270 - loss: 0.3730 - val_accuracy: 0.6207 - val_loss: 0.9953
# Epoch 104/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 336ms/step - accuracy: 0.7937 - loss: 0.4759 - val_accuracy: 0.7241 - val_loss: 1.6444
# Epoch 105/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 354ms/step - accuracy: 0.7647 - loss: 0.4725 - val_accuracy: 0.7586 - val_loss: 1.6417
# Epoch 106/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 346ms/step - accuracy: 0.9089 - loss: 0.3345 - val_accuracy: 0.6897 - val_loss: 0.8743
# Epoch 107/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 336ms/step - accuracy: 0.9329 - loss: 0.2332 - val_accuracy: 0.8276 - val_loss: 1.4447
# Epoch 108/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 333ms/step - accuracy: 0.7516 - loss: 0.4805 - val_accuracy: 0.7586 - val_loss: 1.5437
# Epoch 109/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 344ms/step - accuracy: 0.8549 - loss: 0.3706 - val_accuracy: 0.8621 - val_loss: 0.9858
# Epoch 110/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 344ms/step - accuracy: 0.9316 - loss: 0.2473 - val_accuracy: 0.8276 - val_loss: 1.3323
# Epoch 111/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 333ms/step - accuracy: 0.9265 - loss: 0.2917 - val_accuracy: 0.7931 - val_loss: 1.5620
# Epoch 112/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 341ms/step - accuracy: 0.8608 - loss: 0.2615 - val_accuracy: 0.6897 - val_loss: 1.7047
# Epoch 113/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 333ms/step - accuracy: 0.8697 - loss: 0.3584 - val_accuracy: 0.7931 - val_loss: 1.6718
# Epoch 114/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 343ms/step - accuracy: 0.8694 - loss: 0.2609 - val_accuracy: 0.8966 - val_loss: 0.5939
# Epoch 115/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 331ms/step - accuracy: 0.9105 - loss: 0.3096 - val_accuracy: 0.8621 - val_loss: 1.7088
# Epoch 116/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 360ms/step - accuracy: 0.8318 - loss: 0.2900 - val_accuracy: 0.8621 - val_loss: 1.4122
# Epoch 117/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 348ms/step - accuracy: 0.9103 - loss: 0.2540 - val_accuracy: 0.6897 - val_loss: 3.2301
# Epoch 118/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 338ms/step - accuracy: 0.6862 - loss: 0.6991 - val_accuracy: 0.8276 - val_loss: 0.5102
# Epoch 119/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 336ms/step - accuracy: 0.7616 - loss: 0.5081 - val_accuracy: 0.7931 - val_loss: 1.7332
# Epoch 120/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 334ms/step - accuracy: 0.8805 - loss: 0.3086 - val_accuracy: 0.6552 - val_loss: 2.3496
# Epoch 121/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 335ms/step - accuracy: 0.9225 - loss: 0.2273 - val_accuracy: 0.7586 - val_loss: 1.7311
# Epoch 122/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 343ms/step - accuracy: 0.8950 - loss: 0.2288 - val_accuracy: 0.7586 - val_loss: 1.8855
# Epoch 123/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 329ms/step - accuracy: 0.9535 - loss: 0.1646 - val_accuracy: 0.7241 - val_loss: 2.7190
# Epoch 124/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 332ms/step - accuracy: 0.8238 - loss: 0.3130 - val_accuracy: 0.7586 - val_loss: 2.2200
# Epoch 125/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 329ms/step - accuracy: 0.9076 - loss: 0.3032 - val_accuracy: 0.8621 - val_loss: 1.7392
# Epoch 126/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 353ms/step - accuracy: 0.9111 - loss: 0.1743 - val_accuracy: 0.7931 - val_loss: 2.0898
# Epoch 127/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 365ms/step - accuracy: 0.9321 - loss: 0.1398 - val_accuracy: 0.7241 - val_loss: 2.2101
# Epoch 128/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 346ms/step - accuracy: 0.9439 - loss: 0.1192 - val_accuracy: 0.7931 - val_loss: 2.0038
# Epoch 129/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 333ms/step - accuracy: 0.9675 - loss: 0.1752 - val_accuracy: 0.8621 - val_loss: 1.4976
# Epoch 130/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 352ms/step - accuracy: 0.9207 - loss: 0.1810 - val_accuracy: 0.7241 - val_loss: 1.3597
# Epoch 131/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 337ms/step - accuracy: 0.9579 - loss: 0.0989 - val_accuracy: 0.8621 - val_loss: 2.5805
# Epoch 132/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 353ms/step - accuracy: 0.9066 - loss: 0.1945 - val_accuracy: 0.7931 - val_loss: 1.8207
# Epoch 133/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 335ms/step - accuracy: 0.8442 - loss: 0.3896 - val_accuracy: 0.5862 - val_loss: 2.1971
# Epoch 134/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 338ms/step - accuracy: 0.6396 - loss: 1.2271 - val_accuracy: 0.4828 - val_loss: 1.9758
# Epoch 135/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 360ms/step - accuracy: 0.6438 - loss: 0.7968 - val_accuracy: 0.7931 - val_loss: 1.1330
# Epoch 136/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 344ms/step - accuracy: 0.7003 - loss: 0.6143 - val_accuracy: 0.6552 - val_loss: 0.9918
# Epoch 137/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 348ms/step - accuracy: 0.7885 - loss: 0.5317 - val_accuracy: 0.7586 - val_loss: 1.7284
# Epoch 138/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 346ms/step - accuracy: 0.8431 - loss: 0.3980 - val_accuracy: 0.7586 - val_loss: 1.5394
# Epoch 139/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 341ms/step - accuracy: 0.8824 - loss: 0.2876 - val_accuracy: 0.8276 - val_loss: 2.5307
# Epoch 140/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 341ms/step - accuracy: 0.8746 - loss: 0.3502 - val_accuracy: 0.7931 - val_loss: 2.8600
# Epoch 141/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 345ms/step - accuracy: 0.9397 - loss: 0.2176 - val_accuracy: 0.7931 - val_loss: 2.0595
# Epoch 142/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 348ms/step - accuracy: 0.9449 - loss: 0.1826 - val_accuracy: 0.7586 - val_loss: 3.3460
# Epoch 143/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 340ms/step - accuracy: 0.9098 - loss: 0.1977 - val_accuracy: 0.8276 - val_loss: 1.4442
# Epoch 144/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 345ms/step - accuracy: 0.9215 - loss: 0.2337 - val_accuracy: 0.8276 - val_loss: 1.3494
# Epoch 145/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 340ms/step - accuracy: 0.9541 - loss: 0.1131 - val_accuracy: 0.7931 - val_loss: 2.2894
# Epoch 146/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 338ms/step - accuracy: 0.9893 - loss: 0.1304 - val_accuracy: 0.6897 - val_loss: 4.6365
# Epoch 147/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 337ms/step - accuracy: 0.8555 - loss: 0.3747 - val_accuracy: 0.8276 - val_loss: 1.1401
# Epoch 148/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 357ms/step - accuracy: 0.8649 - loss: 0.2870 - val_accuracy: 0.6552 - val_loss: 1.8406
# Epoch 149/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 326ms/step - accuracy: 0.8487 - loss: 0.3471 - val_accuracy: 0.8621 - val_loss: 1.4206
# Epoch 150/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 333ms/step - accuracy: 0.9672 - loss: 0.1777 - val_accuracy: 0.8966 - val_loss: 1.7273

# %%
 # Access the keys of the training history dictionary
history_adam.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %% [markdown]
# #### Model Accuracy

# %%
# Evaluate the model using the Adam optimizer on the validation set
score_adam = model_adam.evaluate(validation_set,verbose=0)

# Extract the accuracy from the evaluation results
accuracy_adam = 100*score_adam[1]

# Print the accuracy of the CNN model with Adam optimizer
print('Accuracy CNN Model with Adam Optimizer:',accuracy_adam)
# Out:
# Accuracy CNN Model with Adam Optimizer: 79.31034564971924

# %%
# Setting the size of the figure
plt.figure(figsize=(12,7))

# Adding a label to the x-axis
plt.xlabel('Epoch Number',fontsize=15)

# Adding a label to the y-axis
plt.ylabel('Accuracy',fontsize=15)

# Plotting the training set accuracy over epochs
plt.plot(history_adam.history['accuracy'], label = 'training set')

# Plotting the validation set accuracy over epochs
plt.plot(history_adam.history['val_accuracy'], label = 'validation set')

# Adding a legend to the plot to distinguish between training and validation sets
plt.legend()

# Adding a title to the plot
plt.title("Model Accuracy ADAM Optimizer",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Model Accuracy ADAM Optimizer')

# %% [markdown]
# #### Model Loss

# %%
# Create a new figure with a specified size
plt.figure(figsize=(12,7))

# Set the label for the x-axis
plt.xlabel('Epoch Number',fontsize=15)

# Set the label for the y-axis
plt.ylabel('Loss',fontsize=15)

# Plot the training loss over epochs and label it as 'training set'
plt.plot(history_adam.history['loss'], label = 'training set')

# Plot the validation loss over epochs and label it as 'validation set'
plt.plot(history_adam.history['val_loss'], label = 'validation set')

# Display a legend indicating which line corresponds to which dataset
plt.legend()

# Set the title of the plot for model loss
plt.title("Model Loss ADAM Optimizer",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Model Loss ADAM Optimizer')

# %% [markdown]
# ### 3. Using RMSprop Optimizer

# %%
# Using RMSprop Optimizer

#Initialising the CNN model
model_rms = Sequential()

# First Convolution Layer
model_rms.add(Conv2D(filters= 16, kernel_size=2, activation='relu', input_shape=[256, 256, 3]))

# First Pooling Layer
model_rms.add(MaxPooling2D(pool_size=2))

# Second Convolution Layer
model_rms.add(Conv2D(filters=32, kernel_size=2, activation='relu'))

# Second Pooling Layer
model_rms.add(MaxPooling2D(pool_size=2))

# Third Convolution Layer
model_rms.add(Conv2D(filters=32, kernel_size=2, activation='relu'))

# Third Pooling Layer
model_rms.add(MaxPooling2D(pool_size=2))

# Fourth Convolution Layer.
model_rms.add(Conv2D(filters=64, kernel_size=2, activation='relu'))

# Fourth Pooling Layer
model_rms.add(MaxPooling2D(pool_size=2))

# Flattening
model_rms.add(Flatten())

# Fully Connected Layer
model_rms.add(Dense(128, activation="relu"))

# Deactivating 50% of neuron
model_rms.add(Dropout(0.5))

# Output Layer
model_rms.add(Dense(3, activation="softmax"))

# %%
# Display a summary of the model architecture and parameters
model_rms.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)               │ (None, 255, 255, 16)   │           208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 127, 127, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 126, 126, 32)   │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 62, 62, 32)     │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 31, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 30, 30, 64)     │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 15, 15, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 14400)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │     1,843,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,858,387 (7.09 MB)
#  Trainable params: 1,858,387 (7.09 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Compiling and Training the model

# %%
# Display a summary of the model architecture and parameters
from keras.optimizers import RMSprop


# Compile the model with specified configuration
model_rms.compile(
                    # Loss function for training (categorical cross-entropy for multiclass classification)
                    loss = 'categorical_crossentropy',
                    
                    # Optimization algorithm (RMSprop) 
                    optimizer = 'RMSprop', 
                    
                    # Evaluation metric during training and testing (accuracy)
                    metrics=['accuracy'])

# Training the model
history_rms = model_rms.fit(
                                        # Training data generator
                                        training_set,
                                        
                                        # Number of batches per epoch in the training set
                                        steps_per_epoch=len(training_set),
                                        
                                        # Number of training epochs
                                        epochs=150,
                                        
                                        # Validation data for evaluating model performance
                                        validation_data=validation_set,
                                        
                                        # Number of batches per epoch in the validation set
                                        validation_steps = len(validation_set))
# Out:
# Epoch 1/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 371ms/step - accuracy: 0.2967 - loss: 1.6390 - val_accuracy: 0.3448 - val_loss: 1.0873
# Epoch 2/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 336ms/step - accuracy: 0.3490 - loss: 1.1083 - val_accuracy: 0.2759 - val_loss: 1.0889
# Epoch 3/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 317ms/step - accuracy: 0.3686 - loss: 1.1012 - val_accuracy: 0.5862 - val_loss: 1.0925
# Epoch 4/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.4355 - loss: 1.0639 - val_accuracy: 0.3448 - val_loss: 1.0887
# Epoch 5/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.2851 - loss: 1.1011 - val_accuracy: 0.4138 - val_loss: 1.0575
# Epoch 6/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.4158 - loss: 1.0675 - val_accuracy: 0.4138 - val_loss: 1.1873
# Epoch 7/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 328ms/step - accuracy: 0.3178 - loss: 1.0420 - val_accuracy: 0.5517 - val_loss: 1.0174
# Epoch 8/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 351ms/step - accuracy: 0.5102 - loss: 0.9269 - val_accuracy: 0.5517 - val_loss: 0.9192
# Epoch 9/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 331ms/step - accuracy: 0.5505 - loss: 0.9184 - val_accuracy: 0.6897 - val_loss: 0.9215
# Epoch 10/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 317ms/step - accuracy: 0.4928 - loss: 0.9506 - val_accuracy: 0.5517 - val_loss: 0.8067
# Epoch 11/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 337ms/step - accuracy: 0.5275 - loss: 0.8476 - val_accuracy: 0.3448 - val_loss: 1.1967
# Epoch 12/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 327ms/step - accuracy: 0.4310 - loss: 1.0808 - val_accuracy: 0.4828 - val_loss: 1.1469
# Epoch 13/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 319ms/step - accuracy: 0.5644 - loss: 0.7940 - val_accuracy: 0.7241 - val_loss: 0.7482
# Epoch 14/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.5716 - loss: 0.8029 - val_accuracy: 0.7931 - val_loss: 0.7325
# Epoch 15/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 333ms/step - accuracy: 0.7181 - loss: 0.7089 - val_accuracy: 0.6552 - val_loss: 0.7522
# Epoch 16/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 314ms/step - accuracy: 0.6735 - loss: 0.6980 - val_accuracy: 0.8621 - val_loss: 0.6233
# Epoch 17/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 324ms/step - accuracy: 0.6353 - loss: 0.8087 - val_accuracy: 0.7241 - val_loss: 0.9699
# Epoch 18/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 344ms/step - accuracy: 0.6231 - loss: 0.7421 - val_accuracy: 0.6897 - val_loss: 0.6447
# Epoch 19/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 339ms/step - accuracy: 0.6502 - loss: 0.6943 - val_accuracy: 0.8276 - val_loss: 0.6243
# Epoch 20/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.5501 - loss: 0.7295 - val_accuracy: 0.7586 - val_loss: 0.6767
# Epoch 21/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.6919 - loss: 0.7182 - val_accuracy: 0.8621 - val_loss: 0.5594
# Epoch 22/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 313ms/step - accuracy: 0.6455 - loss: 0.6799 - val_accuracy: 0.7931 - val_loss: 0.6399
# Epoch 23/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 319ms/step - accuracy: 0.5010 - loss: 0.7921 - val_accuracy: 0.7586 - val_loss: 0.6254
# Epoch 24/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 317ms/step - accuracy: 0.7276 - loss: 0.6600 - val_accuracy: 0.7586 - val_loss: 0.6913
# Epoch 25/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 334ms/step - accuracy: 0.6482 - loss: 0.6427 - val_accuracy: 0.6897 - val_loss: 1.1420
# Epoch 26/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 334ms/step - accuracy: 0.6365 - loss: 0.6827 - val_accuracy: 0.6207 - val_loss: 1.4224
# Epoch 27/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.7286 - loss: 0.6345 - val_accuracy: 0.7931 - val_loss: 0.7448
# Epoch 28/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 313ms/step - accuracy: 0.7087 - loss: 0.6232 - val_accuracy: 0.7241 - val_loss: 0.6849
# Epoch 29/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 329ms/step - accuracy: 0.7613 - loss: 0.6270 - val_accuracy: 0.7241 - val_loss: 1.1500
# Epoch 30/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.7519 - loss: 0.6991 - val_accuracy: 0.8276 - val_loss: 0.5984
# Epoch 31/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 338ms/step - accuracy: 0.7675 - loss: 0.5846 - val_accuracy: 0.7241 - val_loss: 0.6388
# Epoch 32/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 333ms/step - accuracy: 0.6945 - loss: 0.6718 - val_accuracy: 0.6897 - val_loss: 0.7072
# Epoch 33/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 325ms/step - accuracy: 0.7633 - loss: 0.6177 - val_accuracy: 0.5862 - val_loss: 1.1484
# Epoch 34/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.7752 - loss: 0.5749 - val_accuracy: 0.6207 - val_loss: 0.6192
# Epoch 35/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 356ms/step - accuracy: 0.6308 - loss: 0.6689 - val_accuracy: 0.6552 - val_loss: 1.1604
# Epoch 36/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 334ms/step - accuracy: 0.8013 - loss: 0.4397 - val_accuracy: 0.6552 - val_loss: 0.7002
# Epoch 37/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.7285 - loss: 0.5744 - val_accuracy: 0.8276 - val_loss: 0.6919
# Epoch 38/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 335ms/step - accuracy: 0.7371 - loss: 0.5280 - val_accuracy: 0.6897 - val_loss: 0.6509
# Epoch 39/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 336ms/step - accuracy: 0.6872 - loss: 0.5598 - val_accuracy: 0.6897 - val_loss: 0.7517
# Epoch 40/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.7795 - loss: 0.4961 - val_accuracy: 0.7586 - val_loss: 0.6681
# Epoch 41/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.7824 - loss: 0.5215 - val_accuracy: 0.8276 - val_loss: 0.6363
# Epoch 42/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 352ms/step - accuracy: 0.7858 - loss: 0.4579 - val_accuracy: 0.7586 - val_loss: 1.4697
# Epoch 43/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 329ms/step - accuracy: 0.6997 - loss: 0.6326 - val_accuracy: 0.7241 - val_loss: 1.6524
# Epoch 44/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.7491 - loss: 0.5599 - val_accuracy: 0.8621 - val_loss: 0.5725
# Epoch 45/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 339ms/step - accuracy: 0.8379 - loss: 0.4484 - val_accuracy: 0.7931 - val_loss: 1.1598
# Epoch 46/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.8493 - loss: 0.4726 - val_accuracy: 0.7931 - val_loss: 0.8718
# Epoch 47/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 314ms/step - accuracy: 0.7421 - loss: 0.5532 - val_accuracy: 0.6897 - val_loss: 1.1122
# Epoch 48/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 329ms/step - accuracy: 0.8842 - loss: 0.2960 - val_accuracy: 0.5862 - val_loss: 1.1693
# Epoch 49/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.8678 - loss: 0.4817 - val_accuracy: 0.5862 - val_loss: 0.8354
# Epoch 50/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.6730 - loss: 0.5914 - val_accuracy: 0.8276 - val_loss: 0.6239
# Epoch 51/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 350ms/step - accuracy: 0.8057 - loss: 0.4445 - val_accuracy: 0.7586 - val_loss: 0.7037
# Epoch 52/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 332ms/step - accuracy: 0.7946 - loss: 0.5045 - val_accuracy: 0.6897 - val_loss: 1.3826
# Epoch 53/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 344ms/step - accuracy: 0.8157 - loss: 0.4092 - val_accuracy: 0.7931 - val_loss: 1.3031
# Epoch 54/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 333ms/step - accuracy: 0.8242 - loss: 0.4845 - val_accuracy: 0.8621 - val_loss: 0.5835
# Epoch 55/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.8243 - loss: 0.4224 - val_accuracy: 0.8276 - val_loss: 0.6331
# Epoch 56/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.8338 - loss: 0.3678 - val_accuracy: 0.8276 - val_loss: 0.9964
# Epoch 57/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 324ms/step - accuracy: 0.7696 - loss: 0.4550 - val_accuracy: 0.7586 - val_loss: 1.5560
# Epoch 58/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 336ms/step - accuracy: 0.8047 - loss: 0.4420 - val_accuracy: 0.6207 - val_loss: 1.5794
# Epoch 59/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 313ms/step - accuracy: 0.8848 - loss: 0.3544 - val_accuracy: 0.7586 - val_loss: 2.2012
# Epoch 60/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 325ms/step - accuracy: 0.8943 - loss: 0.3446 - val_accuracy: 0.5517 - val_loss: 1.6239
# Epoch 61/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 327ms/step - accuracy: 0.6782 - loss: 0.5812 - val_accuracy: 0.5862 - val_loss: 1.6728
# Epoch 62/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 326ms/step - accuracy: 0.8882 - loss: 0.2475 - val_accuracy: 0.6552 - val_loss: 1.5508
# Epoch 63/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 317ms/step - accuracy: 0.7836 - loss: 0.4348 - val_accuracy: 0.7241 - val_loss: 3.0396
# Epoch 64/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 338ms/step - accuracy: 0.7643 - loss: 0.5664 - val_accuracy: 0.5517 - val_loss: 1.3388
# Epoch 65/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 329ms/step - accuracy: 0.8614 - loss: 0.2722 - val_accuracy: 0.7586 - val_loss: 1.9899
# Epoch 66/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 349ms/step - accuracy: 0.8883 - loss: 0.2699 - val_accuracy: 0.6207 - val_loss: 1.0024
# Epoch 67/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 343ms/step - accuracy: 0.9425 - loss: 0.2803 - val_accuracy: 0.7241 - val_loss: 2.5579
# Epoch 68/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 318ms/step - accuracy: 0.9047 - loss: 0.3030 - val_accuracy: 0.6552 - val_loss: 1.6656
# Epoch 69/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 325ms/step - accuracy: 0.8032 - loss: 0.4754 - val_accuracy: 0.6897 - val_loss: 0.8816
# Epoch 70/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 325ms/step - accuracy: 0.8813 - loss: 0.2778 - val_accuracy: 0.7586 - val_loss: 1.9454
# Epoch 71/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 318ms/step - accuracy: 0.7985 - loss: 0.5465 - val_accuracy: 0.6897 - val_loss: 1.3148
# Epoch 72/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 338ms/step - accuracy: 0.7700 - loss: 0.7690 - val_accuracy: 0.5517 - val_loss: 1.6143
# Epoch 73/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 327ms/step - accuracy: 0.8610 - loss: 0.3137 - val_accuracy: 0.6897 - val_loss: 1.8232
# Epoch 74/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 318ms/step - accuracy: 0.8357 - loss: 0.4902 - val_accuracy: 0.7586 - val_loss: 0.5556
# Epoch 75/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 340ms/step - accuracy: 0.8872 - loss: 0.2907 - val_accuracy: 0.7241 - val_loss: 1.4625
# Epoch 76/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 335ms/step - accuracy: 0.8412 - loss: 0.3582 - val_accuracy: 0.7586 - val_loss: 1.5886
# Epoch 77/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 317ms/step - accuracy: 0.8900 - loss: 0.3175 - val_accuracy: 0.7241 - val_loss: 1.0006
# Epoch 78/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 326ms/step - accuracy: 0.8604 - loss: 0.2965 - val_accuracy: 0.6897 - val_loss: 1.4293
# Epoch 79/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 332ms/step - accuracy: 0.9105 - loss: 0.2720 - val_accuracy: 0.6207 - val_loss: 2.5497
# Epoch 80/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 318ms/step - accuracy: 0.7370 - loss: 0.5879 - val_accuracy: 0.7241 - val_loss: 1.7158
# Epoch 81/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 315ms/step - accuracy: 0.9065 - loss: 0.2070 - val_accuracy: 0.5862 - val_loss: 1.5618
# Epoch 82/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 333ms/step - accuracy: 0.9713 - loss: 0.1933 - val_accuracy: 0.6897 - val_loss: 0.7799
# Epoch 83/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 317ms/step - accuracy: 0.8944 - loss: 0.1646 - val_accuracy: 0.5862 - val_loss: 2.7717
# Epoch 84/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.8809 - loss: 0.3493 - val_accuracy: 0.7241 - val_loss: 1.5372
# Epoch 85/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.8373 - loss: 0.3891 - val_accuracy: 0.7586 - val_loss: 1.5890
# Epoch 86/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.9199 - loss: 0.2230 - val_accuracy: 0.5517 - val_loss: 1.4315
# Epoch 87/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 349ms/step - accuracy: 0.9007 - loss: 0.2471 - val_accuracy: 0.7241 - val_loss: 1.0257
# Epoch 88/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 334ms/step - accuracy: 0.9287 - loss: 0.1650 - val_accuracy: 0.6552 - val_loss: 1.1110
# Epoch 89/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 338ms/step - accuracy: 0.8709 - loss: 0.2270 - val_accuracy: 0.5172 - val_loss: 1.2477
# Epoch 90/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 326ms/step - accuracy: 0.8657 - loss: 0.4403 - val_accuracy: 0.7241 - val_loss: 1.3030
# Epoch 91/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.9106 - loss: 0.3491 - val_accuracy: 0.6207 - val_loss: 1.5177
# Epoch 92/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 317ms/step - accuracy: 0.8885 - loss: 0.1549 - val_accuracy: 0.6552 - val_loss: 1.8086
# Epoch 93/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 331ms/step - accuracy: 0.9319 - loss: 0.2127 - val_accuracy: 0.7586 - val_loss: 3.8879
# Epoch 94/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.8667 - loss: 0.4399 - val_accuracy: 0.7241 - val_loss: 2.0662
# Epoch 95/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 319ms/step - accuracy: 0.9488 - loss: 0.1379 - val_accuracy: 0.6207 - val_loss: 1.6408
# Epoch 96/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 327ms/step - accuracy: 0.9006 - loss: 0.2417 - val_accuracy: 0.5517 - val_loss: 4.3061
# Epoch 97/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 330ms/step - accuracy: 0.8963 - loss: 0.2795 - val_accuracy: 0.6897 - val_loss: 1.3841
# Epoch 98/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 349ms/step - accuracy: 0.8462 - loss: 0.4073 - val_accuracy: 0.7931 - val_loss: 1.8645
# Epoch 99/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.9403 - loss: 0.1967 - val_accuracy: 0.5172 - val_loss: 3.0413
# Epoch 100/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.9078 - loss: 0.3434 - val_accuracy: 0.7241 - val_loss: 2.6558
# Epoch 101/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 330ms/step - accuracy: 0.8661 - loss: 0.4883 - val_accuracy: 0.5517 - val_loss: 1.8895
# Epoch 102/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 339ms/step - accuracy: 0.8990 - loss: 0.2425 - val_accuracy: 0.6897 - val_loss: 2.3326
# Epoch 103/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 328ms/step - accuracy: 0.8633 - loss: 0.3959 - val_accuracy: 0.6897 - val_loss: 4.0530
# Epoch 104/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 317ms/step - accuracy: 0.8790 - loss: 0.3879 - val_accuracy: 0.5517 - val_loss: 1.8849
# Epoch 105/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 332ms/step - accuracy: 0.8636 - loss: 0.3905 - val_accuracy: 0.7241 - val_loss: 2.5407
# Epoch 106/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.9753 - loss: 0.1518 - val_accuracy: 0.6207 - val_loss: 1.9112
# Epoch 107/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 318ms/step - accuracy: 0.8442 - loss: 0.2528 - val_accuracy: 0.7931 - val_loss: 1.4140
# Epoch 108/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.8627 - loss: 0.3682 - val_accuracy: 0.5862 - val_loss: 1.3377
# Epoch 109/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 350ms/step - accuracy: 0.9627 - loss: 0.1713 - val_accuracy: 0.6897 - val_loss: 1.2145
# Epoch 110/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 329ms/step - accuracy: 0.8978 - loss: 0.2274 - val_accuracy: 0.6552 - val_loss: 1.8433
# Epoch 111/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 327ms/step - accuracy: 0.8147 - loss: 0.5399 - val_accuracy: 0.7586 - val_loss: 1.9701
# Epoch 112/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 328ms/step - accuracy: 0.8849 - loss: 0.4030 - val_accuracy: 0.6897 - val_loss: 1.4689
# Epoch 113/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 332ms/step - accuracy: 0.9638 - loss: 0.1327 - val_accuracy: 0.7586 - val_loss: 1.0777
# Epoch 114/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.9519 - loss: 0.1833 - val_accuracy: 0.7586 - val_loss: 2.0490
# Epoch 115/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 325ms/step - accuracy: 0.8990 - loss: 0.3755 - val_accuracy: 0.7586 - val_loss: 2.6092
# Epoch 116/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.9584 - loss: 0.2450 - val_accuracy: 0.4828 - val_loss: 3.4867
# Epoch 117/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 318ms/step - accuracy: 0.8285 - loss: 0.6051 - val_accuracy: 0.6552 - val_loss: 1.1955
# Epoch 118/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.9191 - loss: 0.1382 - val_accuracy: 0.7931 - val_loss: 2.7834
# Epoch 119/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 324ms/step - accuracy: 0.8657 - loss: 0.3380 - val_accuracy: 0.6897 - val_loss: 1.9158
# Epoch 120/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 342ms/step - accuracy: 0.8995 - loss: 0.2502 - val_accuracy: 0.6897 - val_loss: 2.1075
# Epoch 121/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 330ms/step - accuracy: 0.9753 - loss: 0.0884 - val_accuracy: 0.7931 - val_loss: 3.0330
# Epoch 122/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.9421 - loss: 0.2095 - val_accuracy: 0.7241 - val_loss: 2.3646
# Epoch 123/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.9565 - loss: 0.1311 - val_accuracy: 0.7586 - val_loss: 1.7688
# Epoch 124/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 326ms/step - accuracy: 0.9213 - loss: 0.1466 - val_accuracy: 0.5862 - val_loss: 4.1313
# Epoch 125/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 318ms/step - accuracy: 0.9370 - loss: 0.1867 - val_accuracy: 0.6207 - val_loss: 0.7613
# Epoch 126/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 332ms/step - accuracy: 0.9702 - loss: 0.0951 - val_accuracy: 0.5862 - val_loss: 3.0889
# Epoch 127/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 324ms/step - accuracy: 0.9256 - loss: 0.3213 - val_accuracy: 0.7931 - val_loss: 2.9421
# Epoch 128/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 327ms/step - accuracy: 0.9273 - loss: 0.1562 - val_accuracy: 0.7241 - val_loss: 5.6177
# Epoch 129/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.9267 - loss: 0.3081 - val_accuracy: 0.7586 - val_loss: 3.1132
# Epoch 130/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.9673 - loss: 0.0942 - val_accuracy: 0.7586 - val_loss: 4.2540
# Epoch 131/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 327ms/step - accuracy: 0.9217 - loss: 0.2154 - val_accuracy: 0.7586 - val_loss: 2.7757
# Epoch 132/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 342ms/step - accuracy: 0.9241 - loss: 0.1815 - val_accuracy: 0.7586 - val_loss: 3.2851
# Epoch 133/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 317ms/step - accuracy: 0.9438 - loss: 0.1090 - val_accuracy: 0.7241 - val_loss: 5.5686
# Epoch 134/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 348ms/step - accuracy: 0.9220 - loss: 0.3238 - val_accuracy: 0.7586 - val_loss: 2.3563
# Epoch 135/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 314ms/step - accuracy: 0.9276 - loss: 0.2487 - val_accuracy: 0.6897 - val_loss: 1.8797
# Epoch 136/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.9422 - loss: 0.1695 - val_accuracy: 0.6897 - val_loss: 2.4871
# Epoch 137/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 329ms/step - accuracy: 0.9349 - loss: 0.3335 - val_accuracy: 0.5517 - val_loss: 3.0756
# Epoch 138/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.9865 - loss: 0.0746 - val_accuracy: 0.6897 - val_loss: 1.9866
# Epoch 139/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 324ms/step - accuracy: 0.9579 - loss: 0.0696 - val_accuracy: 0.7241 - val_loss: 2.7020
# Epoch 140/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.9680 - loss: 0.1548 - val_accuracy: 0.8621 - val_loss: 0.9842
# Epoch 141/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 327ms/step - accuracy: 0.9713 - loss: 0.1032 - val_accuracy: 0.7586 - val_loss: 7.1017
# Epoch 142/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 319ms/step - accuracy: 0.8901 - loss: 0.8175 - val_accuracy: 0.8276 - val_loss: 1.8272
# Epoch 143/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 351ms/step - accuracy: 0.9478 - loss: 0.2189 - val_accuracy: 0.7586 - val_loss: 4.8260
# Epoch 144/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 318ms/step - accuracy: 0.9725 - loss: 0.0876 - val_accuracy: 0.7586 - val_loss: 3.0860
# Epoch 145/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 324ms/step - accuracy: 0.9798 - loss: 0.0564 - val_accuracy: 0.5172 - val_loss: 4.5937
# Epoch 146/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 327ms/step - accuracy: 0.9346 - loss: 0.1907 - val_accuracy: 0.6552 - val_loss: 3.2399
# Epoch 147/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.9550 - loss: 0.1033 - val_accuracy: 0.7586 - val_loss: 2.5586
# Epoch 148/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 326ms/step - accuracy: 0.9800 - loss: 0.0271 - val_accuracy: 0.7586 - val_loss: 2.2297
# Epoch 149/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 331ms/step - accuracy: 0.8349 - loss: 0.5866 - val_accuracy: 0.7241 - val_loss: 3.5181
# Epoch 150/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 329ms/step - accuracy: 0.9705 - loss: 0.1534 - val_accuracy: 0.6897 - val_loss: 1.4524

# %%
# Access the keys of the training history dictionary
history_rms.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %% [markdown]
# #### Model Accuracy

# %%
# Evaluate the performance of the 'model_rms' using the 'evaluate' method on the 'validation_set'.
# The 'verbose=0' argument means that the evaluation will be performed silently without progress updates.
score_rms = model_rms.evaluate(validation_set,verbose=0)

# Extract the accuracy metric from the evaluation results.
accuracy_rms = 100*score_rms[1]

# Print the accuracy of the CNN model that used the RMSprop optimizer.
print('Accuracy CNN Model with RMSprop Optimizer:',accuracy_rms)
# Out:
# Accuracy CNN Model with RMSprop Optimizer: 58.62069129943848

# %%
# Set the size of the figure
plt.figure(figsize=(12,7))

# Set the label for the x-axis
plt.xlabel('Epoch Number',fontsize=15)

# Set the label for the y-axis
plt.ylabel('Accuracy',fontsize=15)

# Plot the accuracy values from the training set over epochs
plt.plot(history_adam.history['accuracy'], label = 'training set')

# Plot the accuracy values from the validation set over epochs
plt.plot(history_adam.history['val_accuracy'], label = 'validation set')

# Display a legend indicating which line corresponds to which dataset
plt.legend()

# Set the title for the plot
plt.title("Model Accuracy with RMSprop",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Model Accuracy with RMSprop')

# %% [markdown]
# #### Model Loss

# %%
# Set the size of the figure
plt.figure(figsize=(12,7))

# Set the label for the x-axis
plt.xlabel('Epoch Number',fontsize=15)

# Set the label for the y-axis
plt.ylabel('Loss',fontsize=15)

# Plot the training set loss using the data from the 'loss' key in the 'history_adam' object
plt.plot(history_adam.history['loss'], label = 'training set')\
    
# Plot the validation set loss using the data from the 'val_loss' key in the 'history_adam' object
plt.plot(history_adam.history['val_loss'], label = 'validation set')

# Display a legend indicating which line corresponds to the training set and which one to the validation set
plt.legend()

# Set the title of the plot
plt.title("Model Loss with RMSprop",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Model Loss with RMSprop')

# %% [markdown]
# ### Using AdaGrad Optimizer

# %%
### Using AdaGrad Optimizer

#Initialising the CNN model
model_adagrad = Sequential()

# First Convolution Layer
model_adagrad.add(Conv2D(filters= 16, kernel_size=2, activation='relu', input_shape=[256, 256, 3]))

# First Pooling Layer
model_adagrad.add(MaxPooling2D(pool_size=2))

# Second Convolution Layer
model_adagrad.add(Conv2D(filters=32, kernel_size=2, activation='relu'))

# Second Pooling Layer
model_adagrad.add(MaxPooling2D(pool_size=2))

# Third Convolution Layer
model_adagrad.add(Conv2D(filters=32, kernel_size=2, activation='relu'))

# Third Pooling Layer
model_adagrad.add(MaxPooling2D(pool_size=2))

# Fourth Convolution Layer.
model_adagrad.add(Conv2D(filters=64, kernel_size=2, activation='relu'))

# Fourth Pooling Layer
model_adagrad.add(MaxPooling2D(pool_size=2))

# Flattening
model_adagrad.add(Flatten())

# Fully Connected Layer
model_adagrad.add(Dense(128, activation="relu"))

# Deactivating 50% of neuron
model_adagrad.add(Dropout(0.5))

# Output Layer
model_adagrad.add(Dense(3, activation="softmax"))

# %%
# Display a summary of the model architecture and parameters
model_adagrad.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 255, 255, 16)   │           208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 127, 127, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 126, 126, 32)   │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 62, 62, 32)     │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 31, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 30, 30, 64)     │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 15, 15, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 14400)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │     1,843,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,858,387 (7.09 MB)
#  Trainable params: 1,858,387 (7.09 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Compiling and training the model

# %%
# Importing necessary modules
from keras.optimizers import Adagrad


# Compiling the model with Adagrad optimizer
model_adagrad.compile(
                        # Using categorical cross-entropy as the loss function
                        loss = 'categorical_crossentropy',  
                        
                        # Configuring the model with the Adagrad optimizer
                        optimizer = 'Adagrad', 
                        
                        # Monitoring accuracy as the evaluation metric during training
                        metrics=['accuracy'])


# Training the model using the fit_generator method
history_adagrad = model_adagrad.fit(
                                                # Training data generator
                                                training_set,
                                                
                                                # Number of batches to consider one epoch during training
                                                steps_per_epoch=len(training_set),
                                                
                                                # Number of training epochs
                                                epochs=150,
                                                
                                                # Validation data generator
                                                validation_data=validation_set,
                                                
                                                # Number of batches to consider for validation during training
                                                validation_steps = len(validation_set))
# Out:
# Epoch 1/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.4169 - loss: 1.0983 - val_accuracy: 0.3448 - val_loss: 1.0982
# Epoch 2/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 342ms/step - accuracy: 0.3091 - loss: 1.1056 - val_accuracy: 0.3448 - val_loss: 1.0953
# Epoch 3/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 343ms/step - accuracy: 0.2781 - loss: 1.1128 - val_accuracy: 0.2759 - val_loss: 1.0992
# Epoch 4/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 326ms/step - accuracy: 0.3066 - loss: 1.1219 - val_accuracy: 0.3448 - val_loss: 1.0968
# Epoch 5/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.2952 - loss: 1.1144 - val_accuracy: 0.3448 - val_loss: 1.0962
# Epoch 6/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 332ms/step - accuracy: 0.3701 - loss: 1.1075 - val_accuracy: 0.4483 - val_loss: 1.0920
# Epoch 7/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.3252 - loss: 1.1096 - val_accuracy: 0.4483 - val_loss: 1.0947
# Epoch 8/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.3945 - loss: 1.0910 - val_accuracy: 0.2414 - val_loss: 1.0992
# Epoch 9/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.2818 - loss: 1.1045 - val_accuracy: 0.3103 - val_loss: 1.0991
# Epoch 10/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 314ms/step - accuracy: 0.3894 - loss: 1.0914 - val_accuracy: 0.3103 - val_loss: 1.0968
# Epoch 11/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 326ms/step - accuracy: 0.3536 - loss: 1.0990 - val_accuracy: 0.4828 - val_loss: 1.0956
# Epoch 12/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.2859 - loss: 1.0937 - val_accuracy: 0.4828 - val_loss: 1.0971
# Epoch 13/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 326ms/step - accuracy: 0.3061 - loss: 1.0989 - val_accuracy: 0.3448 - val_loss: 1.0960
# Epoch 14/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 332ms/step - accuracy: 0.3818 - loss: 1.0861 - val_accuracy: 0.2759 - val_loss: 1.0991
# Epoch 15/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 331ms/step - accuracy: 0.2919 - loss: 1.1006 - val_accuracy: 0.2414 - val_loss: 1.0997
# Epoch 16/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.3211 - loss: 1.1044 - val_accuracy: 0.5172 - val_loss: 1.0934
# Epoch 17/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 324ms/step - accuracy: 0.3990 - loss: 1.0954 - val_accuracy: 0.3103 - val_loss: 1.0955
# Epoch 18/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 324ms/step - accuracy: 0.3985 - loss: 1.0956 - val_accuracy: 0.4828 - val_loss: 1.0946
# Epoch 19/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.3249 - loss: 1.1054 - val_accuracy: 0.5172 - val_loss: 1.0946
# Epoch 20/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 315ms/step - accuracy: 0.2822 - loss: 1.1068 - val_accuracy: 0.3793 - val_loss: 1.0955
# Epoch 21/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.4420 - loss: 1.0945 - val_accuracy: 0.4138 - val_loss: 1.0942
# Epoch 22/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 313ms/step - accuracy: 0.4329 - loss: 1.0882 - val_accuracy: 0.3448 - val_loss: 1.0975
# Epoch 23/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.3903 - loss: 1.0935 - val_accuracy: 0.3103 - val_loss: 1.0923
# Epoch 24/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 318ms/step - accuracy: 0.3651 - loss: 1.0971 - val_accuracy: 0.3793 - val_loss: 1.0931
# Epoch 25/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 328ms/step - accuracy: 0.3282 - loss: 1.1021 - val_accuracy: 0.3793 - val_loss: 1.0923
# Epoch 26/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 349ms/step - accuracy: 0.3560 - loss: 1.0919 - val_accuracy: 0.5862 - val_loss: 1.0937
# Epoch 27/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.3617 - loss: 1.0947 - val_accuracy: 0.4138 - val_loss: 1.0959
# Epoch 28/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 325ms/step - accuracy: 0.3638 - loss: 1.1013 - val_accuracy: 0.5517 - val_loss: 1.0873
# Epoch 29/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.4734 - loss: 1.0835 - val_accuracy: 0.5517 - val_loss: 1.0948
# Epoch 30/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 335ms/step - accuracy: 0.2502 - loss: 1.0949 - val_accuracy: 0.5172 - val_loss: 1.0944
# Epoch 31/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 318ms/step - accuracy: 0.3524 - loss: 1.0928 - val_accuracy: 0.4483 - val_loss: 1.0938
# Epoch 32/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.3478 - loss: 1.0969 - val_accuracy: 0.4828 - val_loss: 1.0936
# Epoch 33/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.4612 - loss: 1.0830 - val_accuracy: 0.4483 - val_loss: 1.0964
# Epoch 34/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.3213 - loss: 1.1061 - val_accuracy: 0.4828 - val_loss: 1.0961
# Epoch 35/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 312ms/step - accuracy: 0.4377 - loss: 1.0863 - val_accuracy: 0.5172 - val_loss: 1.0827
# Epoch 36/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.5074 - loss: 1.0796 - val_accuracy: 0.5862 - val_loss: 1.0868
# Epoch 37/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 343ms/step - accuracy: 0.4174 - loss: 1.0940 - val_accuracy: 0.5172 - val_loss: 1.0928
# Epoch 38/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 331ms/step - accuracy: 0.3968 - loss: 1.0906 - val_accuracy: 0.4483 - val_loss: 1.0967
# Epoch 39/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 355ms/step - accuracy: 0.4358 - loss: 1.0895 - val_accuracy: 0.4483 - val_loss: 1.0925
# Epoch 40/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.4929 - loss: 1.0924 - val_accuracy: 0.4828 - val_loss: 1.0904
# Epoch 41/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 326ms/step - accuracy: 0.3498 - loss: 1.0966 - val_accuracy: 0.4828 - val_loss: 1.0899
# Epoch 42/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 319ms/step - accuracy: 0.3220 - loss: 1.0984 - val_accuracy: 0.4483 - val_loss: 1.0948
# Epoch 43/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 329ms/step - accuracy: 0.3394 - loss: 1.1055 - val_accuracy: 0.4483 - val_loss: 1.0796
# Epoch 44/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.3593 - loss: 1.0903 - val_accuracy: 0.5172 - val_loss: 1.0837
# Epoch 45/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.3118 - loss: 1.0980 - val_accuracy: 0.4828 - val_loss: 1.0882
# Epoch 46/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.3148 - loss: 1.1010 - val_accuracy: 0.4483 - val_loss: 1.0922
# Epoch 47/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.4252 - loss: 1.0857 - val_accuracy: 0.4828 - val_loss: 1.0892
# Epoch 48/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 341ms/step - accuracy: 0.3425 - loss: 1.1018 - val_accuracy: 0.3793 - val_loss: 1.0905
# Epoch 49/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 335ms/step - accuracy: 0.3735 - loss: 1.0975 - val_accuracy: 0.5172 - val_loss: 1.0843
# Epoch 50/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 319ms/step - accuracy: 0.5238 - loss: 1.0897 - val_accuracy: 0.4483 - val_loss: 1.0872
# Epoch 51/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 331ms/step - accuracy: 0.3500 - loss: 1.0939 - val_accuracy: 0.5517 - val_loss: 1.0821
# Epoch 52/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 310ms/step - accuracy: 0.3492 - loss: 1.0994 - val_accuracy: 0.6207 - val_loss: 1.0810
# Epoch 53/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 314ms/step - accuracy: 0.4245 - loss: 1.0880 - val_accuracy: 0.4483 - val_loss: 1.0878
# Epoch 54/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 335ms/step - accuracy: 0.3615 - loss: 1.0937 - val_accuracy: 0.5172 - val_loss: 1.0848
# Epoch 55/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 333ms/step - accuracy: 0.3528 - loss: 1.0960 - val_accuracy: 0.5517 - val_loss: 1.0863
# Epoch 56/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 315ms/step - accuracy: 0.3214 - loss: 1.0949 - val_accuracy: 0.4828 - val_loss: 1.0892
# Epoch 57/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 326ms/step - accuracy: 0.3163 - loss: 1.0999 - val_accuracy: 0.5862 - val_loss: 1.0758
# Epoch 58/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 319ms/step - accuracy: 0.4726 - loss: 1.0873 - val_accuracy: 0.5172 - val_loss: 1.0899
# Epoch 59/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 339ms/step - accuracy: 0.5833 - loss: 1.0730 - val_accuracy: 0.5862 - val_loss: 1.0822
# Epoch 60/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 328ms/step - accuracy: 0.4752 - loss: 1.0894 - val_accuracy: 0.4828 - val_loss: 1.0810
# Epoch 61/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 311ms/step - accuracy: 0.4911 - loss: 1.0808 - val_accuracy: 0.4483 - val_loss: 1.0869
# Epoch 62/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.4068 - loss: 1.0892 - val_accuracy: 0.4138 - val_loss: 1.0941
# Epoch 63/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 318ms/step - accuracy: 0.4334 - loss: 1.0830 - val_accuracy: 0.4828 - val_loss: 1.0871
# Epoch 64/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 329ms/step - accuracy: 0.4313 - loss: 1.0926 - val_accuracy: 0.6207 - val_loss: 1.0833
# Epoch 65/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 330ms/step - accuracy: 0.4900 - loss: 1.0842 - val_accuracy: 0.5862 - val_loss: 1.0785
# Epoch 66/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.3032 - loss: 1.0936 - val_accuracy: 0.5517 - val_loss: 1.0790
# Epoch 67/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 332ms/step - accuracy: 0.3929 - loss: 1.0922 - val_accuracy: 0.5862 - val_loss: 1.0798
# Epoch 68/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.3299 - loss: 1.0936 - val_accuracy: 0.4828 - val_loss: 1.0891
# Epoch 69/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.4573 - loss: 1.0887 - val_accuracy: 0.5172 - val_loss: 1.0853
# Epoch 70/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.4603 - loss: 1.0800 - val_accuracy: 0.4483 - val_loss: 1.0778
# Epoch 71/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 348ms/step - accuracy: 0.4555 - loss: 1.0737 - val_accuracy: 0.5517 - val_loss: 1.0695
# Epoch 72/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 319ms/step - accuracy: 0.4173 - loss: 1.0869 - val_accuracy: 0.4138 - val_loss: 1.0872
# Epoch 73/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.5552 - loss: 1.0791 - val_accuracy: 0.5172 - val_loss: 1.0750
# Epoch 74/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.4576 - loss: 1.0778 - val_accuracy: 0.4483 - val_loss: 1.0807
# Epoch 75/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 327ms/step - accuracy: 0.3037 - loss: 1.0969 - val_accuracy: 0.6552 - val_loss: 1.0653
# Epoch 76/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 312ms/step - accuracy: 0.3984 - loss: 1.0856 - val_accuracy: 0.5172 - val_loss: 1.0751
# Epoch 77/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.5115 - loss: 1.0833 - val_accuracy: 0.5172 - val_loss: 1.0767
# Epoch 78/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.3937 - loss: 1.0933 - val_accuracy: 0.5517 - val_loss: 1.0754
# Epoch 79/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 313ms/step - accuracy: 0.4261 - loss: 1.0765 - val_accuracy: 0.6207 - val_loss: 1.0706
# Epoch 80/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 342ms/step - accuracy: 0.3604 - loss: 1.0770 - val_accuracy: 0.6207 - val_loss: 1.0666
# Epoch 81/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 336ms/step - accuracy: 0.4693 - loss: 1.0707 - val_accuracy: 0.5862 - val_loss: 1.0751
# Epoch 82/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 335ms/step - accuracy: 0.3385 - loss: 1.0998 - val_accuracy: 0.6207 - val_loss: 1.0684
# Epoch 83/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 330ms/step - accuracy: 0.5449 - loss: 1.0719 - val_accuracy: 0.5172 - val_loss: 1.0723
# Epoch 84/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.4043 - loss: 1.0900 - val_accuracy: 0.4828 - val_loss: 1.0824
# Epoch 85/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 325ms/step - accuracy: 0.4343 - loss: 1.0773 - val_accuracy: 0.6207 - val_loss: 1.0750
# Epoch 86/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 317ms/step - accuracy: 0.4349 - loss: 1.0806 - val_accuracy: 0.3793 - val_loss: 1.0759
# Epoch 87/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 317ms/step - accuracy: 0.4545 - loss: 1.0739 - val_accuracy: 0.5517 - val_loss: 1.0715
# Epoch 88/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 317ms/step - accuracy: 0.4194 - loss: 1.0881 - val_accuracy: 0.6552 - val_loss: 1.0576
# Epoch 89/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 328ms/step - accuracy: 0.4011 - loss: 1.0922 - val_accuracy: 0.6552 - val_loss: 1.0601
# Epoch 90/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 326ms/step - accuracy: 0.4073 - loss: 1.0809 - val_accuracy: 0.5517 - val_loss: 1.0626
# Epoch 91/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 327ms/step - accuracy: 0.3659 - loss: 1.0846 - val_accuracy: 0.5862 - val_loss: 1.0640
# Epoch 92/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.3647 - loss: 1.0887 - val_accuracy: 0.5862 - val_loss: 1.0628
# Epoch 93/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 348ms/step - accuracy: 0.4475 - loss: 1.0706 - val_accuracy: 0.5517 - val_loss: 1.0657
# Epoch 94/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.4532 - loss: 1.0817 - val_accuracy: 0.5517 - val_loss: 1.0645
# Epoch 95/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 314ms/step - accuracy: 0.5542 - loss: 1.0631 - val_accuracy: 0.6207 - val_loss: 1.0506
# Epoch 96/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 332ms/step - accuracy: 0.3673 - loss: 1.0788 - val_accuracy: 0.5862 - val_loss: 1.0604
# Epoch 97/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.4223 - loss: 1.0825 - val_accuracy: 0.5517 - val_loss: 1.0477
# Epoch 98/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.3448 - loss: 1.1010 - val_accuracy: 0.5517 - val_loss: 1.0569
# Epoch 99/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 315ms/step - accuracy: 0.4404 - loss: 1.0686 - val_accuracy: 0.6552 - val_loss: 1.0547
# Epoch 100/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.4286 - loss: 1.0647 - val_accuracy: 0.5517 - val_loss: 1.0629
# Epoch 101/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 332ms/step - accuracy: 0.3939 - loss: 1.0738 - val_accuracy: 0.6552 - val_loss: 1.0479
# Epoch 102/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.3799 - loss: 1.1030 - val_accuracy: 0.4483 - val_loss: 1.0699
# Epoch 103/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.3886 - loss: 1.0783 - val_accuracy: 0.6207 - val_loss: 1.0567
# Epoch 104/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 324ms/step - accuracy: 0.4188 - loss: 1.0818 - val_accuracy: 0.6207 - val_loss: 1.0617
# Epoch 105/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 354ms/step - accuracy: 0.3003 - loss: 1.0853 - val_accuracy: 0.5862 - val_loss: 1.0550
# Epoch 106/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 328ms/step - accuracy: 0.3672 - loss: 1.0790 - val_accuracy: 0.4828 - val_loss: 1.0677
# Epoch 107/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.4646 - loss: 1.0614 - val_accuracy: 0.5862 - val_loss: 1.0532
# Epoch 108/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.5275 - loss: 1.0663 - val_accuracy: 0.4483 - val_loss: 1.0547
# Epoch 109/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 330ms/step - accuracy: 0.4185 - loss: 1.0724 - val_accuracy: 0.6552 - val_loss: 1.0379
# Epoch 110/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.3491 - loss: 1.0743 - val_accuracy: 0.6897 - val_loss: 1.0291
# Epoch 111/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.4861 - loss: 1.0519 - val_accuracy: 0.5172 - val_loss: 1.0483
# Epoch 112/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 338ms/step - accuracy: 0.3578 - loss: 1.0925 - val_accuracy: 0.4828 - val_loss: 1.0465
# Epoch 113/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 317ms/step - accuracy: 0.4450 - loss: 1.0672 - val_accuracy: 0.5517 - val_loss: 1.0422
# Epoch 114/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.3908 - loss: 1.0884 - val_accuracy: 0.5172 - val_loss: 1.0532
# Epoch 115/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 327ms/step - accuracy: 0.3488 - loss: 1.0753 - val_accuracy: 0.5172 - val_loss: 1.0511
# Epoch 116/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 360ms/step - accuracy: 0.5173 - loss: 1.0404 - val_accuracy: 0.5862 - val_loss: 1.0350
# Epoch 117/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.3763 - loss: 1.1024 - val_accuracy: 0.5862 - val_loss: 1.0473
# Epoch 118/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 319ms/step - accuracy: 0.5589 - loss: 1.0413 - val_accuracy: 0.5517 - val_loss: 1.0332
# Epoch 119/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 310ms/step - accuracy: 0.5096 - loss: 1.0668 - val_accuracy: 0.5862 - val_loss: 1.0390
# Epoch 120/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 315ms/step - accuracy: 0.4046 - loss: 1.0663 - val_accuracy: 0.5172 - val_loss: 1.0415
# Epoch 121/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.4612 - loss: 1.0518 - val_accuracy: 0.6207 - val_loss: 1.0302
# Epoch 122/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 313ms/step - accuracy: 0.3317 - loss: 1.0749 - val_accuracy: 0.4828 - val_loss: 1.0490
# Epoch 123/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.4132 - loss: 1.0900 - val_accuracy: 0.6552 - val_loss: 1.0250
# Epoch 124/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 313ms/step - accuracy: 0.3875 - loss: 1.0671 - val_accuracy: 0.5517 - val_loss: 1.0425
# Epoch 125/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.4225 - loss: 1.0771 - val_accuracy: 0.4483 - val_loss: 1.0355
# Epoch 126/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 330ms/step - accuracy: 0.5030 - loss: 1.0485 - val_accuracy: 0.5517 - val_loss: 1.0179
# Epoch 127/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 340ms/step - accuracy: 0.4882 - loss: 1.0585 - val_accuracy: 0.5862 - val_loss: 1.0255
# Epoch 128/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 334ms/step - accuracy: 0.4211 - loss: 1.0542 - val_accuracy: 0.5172 - val_loss: 1.0365
# Epoch 129/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 314ms/step - accuracy: 0.3765 - loss: 1.0665 - val_accuracy: 0.5862 - val_loss: 1.0339
# Epoch 130/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 317ms/step - accuracy: 0.5428 - loss: 1.0264 - val_accuracy: 0.6552 - val_loss: 1.0236
# Epoch 131/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 330ms/step - accuracy: 0.2997 - loss: 1.0590 - val_accuracy: 0.3793 - val_loss: 1.0568
# Epoch 132/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 324ms/step - accuracy: 0.3832 - loss: 1.0655 - val_accuracy: 0.4483 - val_loss: 1.0405
# Epoch 133/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 318ms/step - accuracy: 0.3325 - loss: 1.0601 - val_accuracy: 0.5862 - val_loss: 1.0190
# Epoch 134/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.3285 - loss: 1.0627 - val_accuracy: 0.5517 - val_loss: 1.0354
# Epoch 135/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.5474 - loss: 1.0493 - val_accuracy: 0.6552 - val_loss: 1.0127
# Epoch 136/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 312ms/step - accuracy: 0.4813 - loss: 1.0596 - val_accuracy: 0.6552 - val_loss: 1.0071
# Epoch 137/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 328ms/step - accuracy: 0.3569 - loss: 1.0879 - val_accuracy: 0.6207 - val_loss: 1.0171
# Epoch 138/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.4330 - loss: 1.0581 - val_accuracy: 0.4828 - val_loss: 1.0404
# Epoch 139/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 341ms/step - accuracy: 0.4560 - loss: 1.0739 - val_accuracy: 0.5517 - val_loss: 1.0311
# Epoch 140/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 325ms/step - accuracy: 0.4815 - loss: 1.0393 - val_accuracy: 0.7241 - val_loss: 0.9953
# Epoch 141/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 319ms/step - accuracy: 0.5638 - loss: 1.0361 - val_accuracy: 0.5862 - val_loss: 1.0003
# Epoch 142/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.4510 - loss: 1.0404 - val_accuracy: 0.5862 - val_loss: 1.0044
# Epoch 143/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 336ms/step - accuracy: 0.3954 - loss: 1.0720 - val_accuracy: 0.6207 - val_loss: 1.0233
# Epoch 144/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 319ms/step - accuracy: 0.4816 - loss: 1.0435 - val_accuracy: 0.5517 - val_loss: 1.0122
# Epoch 145/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 318ms/step - accuracy: 0.4477 - loss: 1.0215 - val_accuracy: 0.5517 - val_loss: 1.0191
# Epoch 146/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 327ms/step - accuracy: 0.3685 - loss: 1.0868 - val_accuracy: 0.6207 - val_loss: 0.9963
# Epoch 147/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.4521 - loss: 1.0336 - val_accuracy: 0.5517 - val_loss: 1.0195
# Epoch 148/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 331ms/step - accuracy: 0.4305 - loss: 1.0596 - val_accuracy: 0.5862 - val_loss: 0.9951
# Epoch 149/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 319ms/step - accuracy: 0.4619 - loss: 1.0379 - val_accuracy: 0.6207 - val_loss: 0.9843
# Epoch 150/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 353ms/step - accuracy: 0.5209 - loss: 1.0284 - val_accuracy: 0.5862 - val_loss: 1.0056

# %%
# Access the keys of the training history dictionary
history_adagrad.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %% [markdown]
# #### Model Accuracy

# %%
score_adagrad = model_adagrad.evaluate(validation_set,verbose=0)
accuracy_adagrad = 100*score_adagrad[1]
print('Accuracy CNN Model with Adagrad Optimizer',accuracy_adagrad)
# Out:
# Accuracy CNN Model with Adagrad Optimizer 65.51724076271057

# %%
# Setting the size of the figure (width, height)
plt.figure(figsize=(12,7))

# Adding a label to the x-axis
plt.xlabel('Epoch Number',fontsize=15)

# Adding a label to the y-axis
plt.ylabel('Accuracy',fontsize=15)

# Plotting the training set accuracy over epochs
plt.plot(history_adagrad.history['accuracy'], label = 'training set')

# Plotting the validation set accuracy over epochs
plt.plot(history_adagrad.history['val_accuracy'], label = 'validation set')

# Adding a legend to distinguish between training and validation sets
plt.legend()

# Adding a title to the plot
plt.title("Model Accuracy with AdaGrad Optimizer",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Model Accuracy with AdaGrad Optimizer')

# %% [markdown]
# #### Model Loss

# %%
# Set the figure size for the plot
plt.figure(figsize=(12,7))

# Set the label for the x-axis (horizontal axis)
plt.xlabel('Epoch Number',fontsize=15)

# Set the label for the y-axis (vertical axis)
plt.ylabel('Loss',fontsize=15)

# Plot the training loss over epochs and label it as 'training set'
plt.plot(history_adagrad.history['loss'], label = 'training set')

# Plot the validation loss over epochs and label it as 'validation set'
plt.plot(history_adagrad.history['val_loss'], label = 'validation set')

# Display a legend to differentiate between the training and validation sets
plt.legend()

# Set the title for the plot
plt.title("Model Loss with AdaGrad Optimizer",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Model Loss with AdaGrad Optimizer')

# %% [markdown]
# ## Model Comparison based on Optimizers

# %%
# List of accuracy values for different optimizers
accuracy = [accuracy_sgd, accuracy_adam, accuracy_rms, accuracy_adagrad]


# List of optimizer names
optimizers = ["SGD", "ADAM", "RMSprop", "ADAGRAD"]    


# Loop through each optimizer and print the corresponding accuracy
for i in range(len(optimizers)):
    print("The acuuracy achieved using "+optimizers[i]+" is: "+str(accuracy[i])+" %")
# Out:
# The acuuracy achieved using SGD is: 58.62069129943848 %
# The acuuracy achieved using ADAM is: 79.31034564971924 %
# The acuuracy achieved using RMSprop is: 58.62069129943848 %
# The acuuracy achieved using ADAGRAD is: 65.51724076271057 %

# %% [markdown]
# ### Comparing accuracy using Bar Plot

# %%
# Set the size of the figure
plt.figure(figsize=(10,6))

# Set labels for the x and y axes
plt.xlabel("Optimizers")
plt.ylabel("Accuracy")

# Create a bar plot using seaborn
ax=sns.barplot(x=optimizers,y=accuracy)

# Add labels to the bars in the plot
for label in ax.containers:
    ax.bar_label(label)
    
# Adjust the layout to prevent overlapping of labels
plt.tight_layout()

# Set the tick label size
plt.tick_params(labelsize=14)

# %% [markdown]
# ## Conclusion
#
# This project successfully developed a deep learning model capable of classifying three major rice leaf diseases: leaf blast, bacterial leaf blight, and brown spot.
#
# Beyond simply classifying rice leaf diseases, this project has the potential to revolutionize rice farming and contribute to global food security.

# %% [markdown]
# ## Challenges Faced
#
#
#     1. Data quality issues: Inconsistent image resolution, lighting conditions, and annotations added complexity.
#
#     2. Class imbalance: The distribution of disease classes might be skewed, requiring careful balancing techniques.
#
#     3. Limited dataset size: Collecting sufficient diverse data for all three diseases, especially rare ones, was challenging.
#
#     4. Choosing the right architecture: Selecting the optimal deep learning architecture for the specific dataset and task was crucial.
#
#     5. Hyperparameter optimization: Tuning numerous parameters like learning rate and batch size significantly impacted performance.
#
#     6. Over-fitting and under-fitting: Balancing model complexity to avoid over-fitting while ensuring sufficient learning capacity was challenging.
#
#     7. Training time: The current deep learning model developed for rice disease classification suffers from a significant drawback: excessively long training times. This extended training duration poses several challenges.
#
#     8. Choosing effective augmentation techniques: Selecting the optimal data augmentation methods to improve model generalizability was crucial.
#
#     9. Choosing appropriate metrics: Selecting the most relevant metrics like F1-score or precision-recall for accurate model evaluation was crucial.
#
#     10. Adaptability to diverse agricultural practices: Making the model and app adaptable to different rice varieties, farming methods, and regional conditions was crucial for wider impact.
#
#
# These challenges highlight the complexities of developing and deploying AI-based solutions in agriculture. Addressing these challenges through further research, collaboration, and innovative solutions can pave the way for a more sustainable and disease-resilient future for rice farming.
